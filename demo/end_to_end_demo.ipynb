# %%
import os
import sys
import logging
import warnings
import pandas as pd

from pprint import pprint
from cocoon.core.llm.bedrock import BedrockLLM
from cocoon.core.embeddings.bedrock import BedrockEmbeddings
from cocoon.cluster_service import compute_cluster
from cocoon.search_service import find_similar_indices, find_entity_relation_matches_and_cluster
from cocoon.embedding_service import initialize_faiss_index_from_embeddings, create_embeddings
from cocoon.output_service import generate_output

warnings.filterwarnings("ignore")
logging.basicConfig(stream=sys.stdout, level=logging.INFO, format="%(levelname)s - %(message)s")

# %% [markdown]
# ## 1. Basic setup

# %%
# Set AWS Profile
os.environ["AWS_DEFAULT_PROFILE"] = "sagar-wip-cli"

# %%
# Basic config for path/location settings
output_model_name = "titan_g1"

folder_name = "testing"
input_file_name = "EOS_Run1"

files = {
    # Pre-computed embeddings for NAICS dataset
    "embeddings": f's3://esgflo-wip-eu-dev-rightwhale-vault-store/scope3/naics/{output_model_name}_embeddings_output.csv',
    
    # Location of input csv file
    "data": f's3://esgflo-wip-eu-dev-rightwhale-vault-store/scope3/{folder_name}/{input_file_name}.csv',
    # Location of embeddings computed based on the input csv file
    "embedded_data": f's3://esgflo-wip-eu-dev-rightwhale-vault-store/scope3/{folder_name}/{input_file_name}_embedded.csv',
    # Location of the output csv file
    "output": f's3://esgflo-wip-eu-dev-rightwhale-vault-store/scope3/{folder_name}/{input_file_name}_output.csv',
}

# %% [markdown]
# ## 2. Read Files
#
# This section deals with reading the input file and the pre-computed embeddings of NAICS database from the location provided above.

# %% [markdown]
# ### 2.1. Input File

# %%
# Read the data file
data_df = pd.read_csv(files["data"], encoding="latin-1")
data_df = data_df[data_df.columns[-2:]]
data_df.columns = ["description1", "group_name"]
data_df = data_df[["group_name", "description1"]]

# Extract the columns to use in the future
columns_to_use = data_df.columns

# Create a label i.e., a concatenation of all the useful columns
data_df["label"] = data_df.apply(lambda x: ",".join(x), axis=1)

# Display the top 5 rows
data_df.head()
# Out:
# INFO - Credentials found in config file: ~/.aws/config
#            group_name                              description1  \
# 0              Drives                              X-axis drive
# 1   Other accessories                              Z-guide used
# 2  Modular assemblies                             Dosing system
# 3             Coolers  Cooling system air-cooled 1.5kW complete
# 4             Scanner                       Scanner head system
#
#                                               label
# 0                               Drives,X-axis drive
# 1                    Other accessories,Z-guide used
# 2                  Modular assemblies,Dosing system
# 3  Coolers,Cooling system air-cooled 1.5kW complete
# 4                       Scanner,Scanner head system

# %% [markdown]
# ### 2.2. Pre-computed Embeddings of NAICS

# %%
# Load NAICS embeddings
reference_df = pd.read_csv(files["embeddings"])

# %%
reference_df.head()
# Out:
#                                                label index_ids  \
# 0                     Abrasive Product Manufacturing     [292]
# 1                             Adhesive Manufacturing     [253]
# 2  Administrative Management and General Manageme...     [800]
# 3                               Advertising Agencies     [811]
# 4         Advertising Material Distribution Services     [817]
#
#                                     2017 NAICS Title  \
# 0                     Abrasive Product Manufacturing
# 1                             Adhesive Manufacturing
# 2  Administrative Management and General Manageme...
# 3                               Advertising Agencies
# 4         Advertising Material Distribution Services
#
#                                            embedding
# 0  [0.828125, 0.47851562, 0.32421875, 0.3125, -0....
# 1  [0.8046875, -0.018798828, 0.21289062, 1.328125...
# 2  [-0.14453125, -0.24609375, 0.41015625, -0.3828...
# 3  [-0.3515625, 0.203125, 0.38671875, 0.58203125,...
# 4  [0.3359375, 0.19042969, 0.088378906, 0.5429687...

# %% [markdown]
# ## 3. Create embeddings of the `label` column in the input data

# %%
# Initialize the Embedding class
# Here, we're using the Titan-G1 Model from Bedrock

embed_model = BedrockEmbeddings(
    model_id="amazon.titan-embed-text-v1",
    aws_region_name="eu-central-1",
    dims=1536
)
# Out:
# INFO - Credentials found in config file: ~/.aws/config

# %%
# Create the embeddings of the `label` column in the input data
# Save the embeddings dataframe in the `output_csv_filepath` location

input_embedded_df = create_embeddings(
    embed_model = embed_model,
    df = data_df,
    output_csv_filepath = files["embedded_data"]
)
# Out:
# INFO - 'amazon.titan-embed-text-v1' used for Embedding Text
# INFO - All labels already embedded.

# %%
input_embedded_df.head()
# Out:
#                                                label index_ids  \
# 0  AMCM Customized System M,Customized M 290-1 1k...       [5]
# 1       CO_ laser,CO2 laser FSV30SAG (30W, AIR, OEM)      [21]
# 2     Coolers,Cooler 1.5kW air/water cooler complete      [31]
# 3     Coolers,Cooler 4.5kW air/water cooler complete      [18]
# 4   Coolers,Cooling system air-cooled 1.5kW complete       [3]
#
#                  group_name                              description1  \
# 0  AMCM Customized System M        Customized M 290-1 1kW Digital Can
# 1                 CO_ laser        CO2 laser FSV30SAG (30W, AIR, OEM)
# 2                   Coolers    Cooler 1.5kW air/water cooler complete
# 3                   Coolers    Cooler 4.5kW air/water cooler complete
# 4                   Coolers  Cooling system air-cooled 1.5kW complete
#
#                                            embedding
# 0  [-0.140625, 0.42578125, -0.439453125, -0.03295...
# 1  [-0.16015625, 0.53125, 0.34375, -0.146484375, ...
# 2  [-0.609375, 1.1171875, -0.63671875, -0.1455078...
# 3  [-0.5, 1.078125, -0.75390625, -0.2119140625, -...
# 4  [-0.267578125, 1.453125, -0.5390625, 0.2470703...

# %% [markdown]
# ## 4. Initialize FAISS Index from NAICS Embeddings

# %%
# Load FAISS index
index = initialize_faiss_index_from_embeddings(
    embed_model=embed_model,
    df=reference_df
)

# %% [markdown]
# ## 5. Find Similar between Input Label Embeddings and NAICS Embeddings

# %%
# Find similar indexes between input embedded df and database index
distances, indexes = find_similar_indices(
    input_embedded_df,
    index
)

# %% [markdown]
# ## 6. Perform Entiry Relation Match and Clustering between Input Emeddings <> NAICS Embeddings <> Similar Indices

# %%
# Initialize the LLM model
# We're using the Claude Sonnet from AWS Bedrock

llm = BedrockLLM(
    model_id="anthropic.claude-3-sonnet-20240229-v1:0",
    region_name="us-east-1",
    model_kwargs={
        "temperature": 1
    }
)

# %%
# Perform the matching
find_entity_relation_matches_and_cluster(
    input_df = input_embedded_df, 
    similar_indexes = indexes, 
    refernece_df = reference_df, 
    llm = llm,
    columns_to_use=columns_to_use
)
# Out:
# INFO - Begin processing entity match for 43 rows
# INFO - 21 rows remain...
# INFO - 10 rows remain...
# INFO - Completed processing entity match

# %%
# Compute the cluster found
clusters = compute_cluster(input_embedded_df)

# %%
clusters
# Out:
# {0: [],
#  1: [7,
#   8,
#   9,
#   10,
#   12,
#   13,
#   14,
#   15,
#   16,
#   17,
#   18,
#   19,
#   20,
#   22,
#   26,
#   30,
#   31,
#   33,
#   35,
#   38],
#  2: [4],
#  3: [5, 6],
#  11: [],
#  21: [],
#  23: [24, 25, 27],
#  28: [39, 40, 41],
#  29: [],
#  32: [],
#  34: [],
#  36: [37],
#  42: []}

# %% [markdown]
# ## 7. Generate output

# %%
output = generate_output(input_embedded_df, clusters)

# %%
pprint(output)
# Out:
# [{'exact_match': {'entity': [],
#                   'reason': 'There is no exact match among the reference '
#                             'entities for the customized digital control '
#                             'system described in the input entity.'},
#   'general': {'entity': ['All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing',
#                          'All Other Miscellaneous Electrical Equipment and '
#                          'Component Manufacturing',
#                          'Air-Conditioning and Warm Air Heating Equipment and '
#                          'Commercial and Industrial Refrigeration Equipment '
#                          'Manufacturing',
#                          'Measuring Dispensing and Other Pumping Equipment '
#                          'Manufacturing',
#                          'Radio and Television Broadcasting and Wireless '
#                          'Communications Equipment Manufacturing',
#                          'Speed Changer Industrial High-Speed Drive and Gear '
#                          'Manufacturing',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing'],
#               'reason': 'These entities are general categories that could '
#                         'potentially encompass the customized digital control '
#                         'system described in the input entity.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be a '
#                                          'customized digital control system '
#                                          'for industrial machinery or '
#                                          'equipment, possibly related to air '
#                                          'conditioning, heating, or '
#                                          'refrigeration systems.',
#                  'entity': {'description1': 'Customized M 290-1 1kW Digital '
#                                             'Can',
#                             'group_name': 'AMCM Customized System M'}},
#   'related': {'additional_assumption': {'entity': ['Instruments and Related '
#                                                    'Products Manufacturing for '
#                                                    'Measuring Displaying and '
#                                                    'Controlling Industrial '
#                                                    'Process Variables',
#                                                    'Automatic Environmental '
#                                                    'Control Manufacturing for '
#                                                    'Residential Commercial and '
#                                                    'Appliance Use'],
#                                         'reason': 'Some reference entities '
#                                                   'require additional '
#                                                   'assumptions beyond what is '
#                                                   'provided in the input '
#                                                   'entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicting '
#                                                   'assumptions among the '
#                                                   'reference entities for the '
#                                                   'input entity.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match for the given input '
#                             'entity among the reference entities.'},
#   'general': {'entity': ['Air-Conditioning and Warm Air Heating Equipment and '
#                          'Commercial and Industrial Refrigeration Equipment '
#                          'Manufacturing',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing',
#                          'All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing',
#                          'All Other Miscellaneous Manufacturing',
#                          'Instruments and Related Products Manufacturing for '
#                          'Measuring Displaying and Controlling Industrial '
#                          'Process Variables',
#                          'Metal Coating Engraving except Jewelry and '
#                          'Silverware and Allied Services to Manufacturers'],
#               'reason': 'These entities are related to manufacturing equipment '
#                         'or processes, which could potentially involve the use '
#                         'of a CO2 laser system.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be a CO2 '
#                                          'laser system used for industrial or '
#                                          'manufacturing purposes.',
#                  'entity': {'description1': 'CO2 laser FSV30SAG (30W, AIR, '
#                                             'OEM)',
#                             'group_name': 'CO_ laser'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'The input entity does not '
#                                                   'provide any additional '
#                                                   'assumptions that cannot be '
#                                                   'verified from the given '
#                                                   'information.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities directly conflict '
#                                                   'with the details provided '
#                                                   'in the input entity.'}},
#   'similar_to': [{'description1': 'Build platform DirectBase Al30',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Build platform DirectBase S22',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Build platform M400 steel',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Build platform titanium Ti64 (Ti6Al4V)',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'X-axis drive', 'group_name': 'Drives'},
#                  {'description1': 'Model Yb-Fiber Laser YLR-200-AC-Y14',
#                   'group_name': 'Fiber laser'},
#                  {'description1': 'YLR-400-SM-EOS ytterbium fiber laser',
#                   'group_name': 'Fiber laser'},
#                  {'description1': 'YLR-400WC-Y14 laser with',
#                   'group_name': 'Fiber laser'},
#                  {'description1': "Ytterbium fiber laser 'EOS-4' model YLR-",
#                   'group_name': 'Fiber laser'},
#                  {'description1': 'EOS M 290 laser sinter system',
#                   'group_name': 'M2xx customer system'},
#                  {'description1': 'EOS M 290 laser sinter system (Std, MP1)',
#                   'group_name': 'M2xx customer system'},
#                  {'description1': 'EOS M 400-4 stand alone',
#                   'group_name': 'M4xx customer system'},
#                  {'description1': 'EOS M 400-4 stand alone (USA)',
#                   'group_name': 'M4xx customer system'},
#                  {'description1': 'Build platform',
#                   'group_name': 'Manufactured parts'},
#                  {'description1': 'New powder container',
#                   'group_name': 'Material handling'},
#                  {'description1': 'Coater complete P7xx assembly',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Controller Charon RevC, 256MB RAM, MPC52',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Exchange frame 676',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'EOSINT P396 laser sintering machine used',
#                   'group_name': 'P3xx customer system'},
#                  {'description1': 'hurryScan 20 scan module 1080nm, with AKS',
#                   'group_name': 'Scanner'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'None of the reference entities precisely matches '
#                             "the input entity's description of a 1.5kW "
#                             'air/water cooler.'},
#   'general': {'entity': ['Air-Conditioning and Warm Air Heating Equipment and '
#                          'Commercial and Industrial Refrigeration Equipment '
#                          'Manufacturing',
#                          'Plumbing and Heating Equipment and Supplies '
#                          'Hydronics Merchant Wholesalers',
#                          'Warm Air Heating and Air-Conditioning Equipment and '
#                          'Supplies Merchant Wholesalers',
#                          'Steam and Air-Conditioning Supply',
#                          'Refrigeration Equipment and Supplies Merchant '
#                          'Wholesalers',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing',
#                          'All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing'],
#               'reason': 'These entities cover general categories related to '
#                         'cooling, heating, air conditioning, and refrigeration '
#                         'equipment manufacturing and distribution.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be '
#                                          'describing an air/water cooler with '
#                                          'a cooling capacity of 1.5kW, likely '
#                                          'used for industrial or commercial '
#                                          'cooling applications.',
#                  'entity': {'description1': 'Cooler 1.5kW air/water cooler '
#                                             'complete',
#                             'group_name': 'Coolers'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities requires '
#                                                   'additional assumptions '
#                                                   'beyond the details provided '
#                                                   'in the input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities appears to '
#                                                   'conflict with the given '
#                                                   'details of the input '
#                                                   'entity.'}},
#   'similar_to': [{'description1': 'Cooling system air-cooled 1.5kW complete',
#                   'group_name': 'Coolers'}]},
#  {'exact_match': {'entity': ['Air-Conditioning and Warm Air Heating Equipment '
#                              'and Commercial and Industrial Refrigeration '
#                              'Equipment Manufacturing'],
#                   'reason': 'The input entity is an air/water cooler unit, '
#                             'which matches the description of an air '
#                             'conditioning and refrigeration equipment '
#                             'manufacturing entity.'},
#   'general': {'entity': ['Plumbing and Heating Equipment and Supplies '
#                          'Hydronics Merchant Wholesalers',
#                          'Steam and Air-Conditioning Supply',
#                          'Warm Air Heating and Air-Conditioning Equipment and '
#                          'Supplies Merchant Wholesalers',
#                          'Refrigeration Equipment and Supplies Merchant '
#                          'Wholesalers',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing'],
#               'reason': 'These entities are related to the broader categories '
#                         'of heating, ventilation, air conditioning, and '
#                         'refrigeration equipment and supplies.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be '
#                                          'describing an air/water cooler unit '
#                                          'used for cooling or air conditioning '
#                                          'purposes.',
#                  'entity': {'description1': 'Cooler 4.5kW air/water cooler '
#                                             'complete',
#                             'group_name': 'Coolers'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'There are no additional '
#                                                   'assumptions made.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicted '
#                                                   'assumptions.'}},
#   'similar_to': [{'description1': 'Laser cooler air/water P802-18644-AW',
#                   'group_name': 'Coolers'},
#                  {'description1': 'Neslab Thermo Flex 2500 air-water cooler',
#                   'group_name': 'Coolers'}]},
#  {'exact_match': {'entity': [],
#                   'reason': "There doesn't seem to be an exact match among the "
#                             "reference entities for 'Cut pieces' and 'Exchange "
#                             "frame'."},
#   'general': {'entity': ['Showcase Partition Shelving and Locker Manufacturing',
#                          'Sewing Needlework and Piece Goods Stores',
#                          'Piece Goods Notions and Other Dry Goods Merchant '
#                          'Wholesalers',
#                          'Upholstered Household Furniture Manufacturing'],
#               'reason': 'These entities are related to the general concept of '
#                         'manufacturing or processing materials, which could '
#                         'include cutting or exchanging frames.'},
#   'input_data': {'ai_input_description': "The input entity 'Cut pieces' with "
#                                          "description 'Exchange frame' seems "
#                                          'to be related to the manufacturing '
#                                          'or processing of cut materials such '
#                                          'as wood, leather, or textiles.',
#                  'entity': {'description1': 'Exchange frame',
#                             'group_name': 'Cut pieces'}},
#   'related': {'additional_assumption': {'entity': ['Cut Stock Resawing Lumber '
#                                                    'and Planing',
#                                                    'Engineered Wood Member '
#                                                    'except Truss Manufacturing',
#                                                    'Special Die and Tool Die '
#                                                    'Set Jig and Fixture '
#                                                    'Manufacturing',
#                                                    'Lumber Plywood Millwork '
#                                                    'and Wood Panel Merchant '
#                                                    'Wholesalers'],
#                                         'reason': "The input entity doesn't "
#                                                   'provide enough details to '
#                                                   'determine the specific type '
#                                                   'of material being cut or '
#                                                   'processed.'},
#               'conflicted_assumption': {'entity': ['Folding Paperboard Box '
#                                                    'Manufacturing',
#                                                    'All Other Leather Good and '
#                                                    'Allied Product '
#                                                    'Manufacturing'],
#                                         'reason': "The description 'Exchange "
#                                                   "frame' conflicts with "
#                                                   'entities related to '
#                                                   'manufacturing or processing '
#                                                   'materials.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': [],
#                   'reason': "There is no exact match for the specific 'Blade "
#                             "cassette II (blue) coater P7' mentioned in the "
#                             'input entity.'},
#   'general': {'entity': ['All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing',
#                          'Other Metal Valve and Pipe Fitting Manufacturing',
#                          'Air-Conditioning and Warm Air Heating Equipment and '
#                          'Commercial and Industrial Refrigeration Equipment '
#                          'Manufacturing',
#                          'Guided Missile and Space Vehicle Propulsion Unit and '
#                          'Propulsion Unit Parts Manufacturing'],
#               'reason': 'These entities are related to general manufacturing '
#                         'or machinery categories that the input entity could '
#                         'potentially fall under.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be related '
#                                          'to some kind of manufacturing '
#                                          'equipment or machinery, specifically '
#                                          'a blade cassette or coater used in a '
#                                          'manufacturing process.',
#                  'entity': {'description1': 'Blade cassette II (blue) coater '
#                                             'P7',
#                             'group_name': 'Manufactured parts'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'The input entity does not '
#                                                   'provide enough information '
#                                                   'to make additional '
#                                                   'assumptions about the '
#                                                   'specific manufacturing '
#                                                   'process or industry it is '
#                                                   'used in.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicting '
#                                                   'assumptions since the input '
#                                                   'entity is quite specific.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': [],
#                   'reason': 'None of the reference entities directly matches a '
#                             'docking station.'},
#   'general': {'entity': ['Other Warehousing and Storage',
#                          'Conveyor and Conveying Equipment Manufacturing',
#                          'Construction Mining and Forestry Machinery and '
#                          'Equipment Rental and Leasing'],
#               'reason': 'These entities broadly cover material handling '
#                         'equipment and systems.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be '
#                                          'related to material handling '
#                                          'equipment or systems, specifically a '
#                                          'docking station used for '
#                                          'loading/unloading materials.',
#                  'entity': {'description1': 'Docking station P3',
#                             'group_name': 'Material handling'}},
#   'related': {'additional_assumption': {'entity': ['Industrial Truck Tractor '
#                                                    'Trailer and Stacker '
#                                                    'Machinery Manufacturing',
#                                                    'General Freight Trucking '
#                                                    'Long-Distance Less Than '
#                                                    'Truckload'],
#                                         'reason': 'Some entities require '
#                                                   'additional assumptions '
#                                                   'beyond just material '
#                                                   'handling.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicting '
#                                                   'assumptions based on the '
#                                                   'given information.'}},
#   'similar_to': [{'description1': 'MQS complete',
#                   'group_name': 'Material handling'},
#                  {'description1': 'Multibox',
#                   'group_name': 'Material handling'},
#                  {'description1': 'Powder conveyor IPCM-M extra',
#                   'group_name': 'Material handling'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match among the reference '
#                             "entities for the specific 'IPCM-M extra' "
#                             'screening system.'},
#   'general': {'entity': ['Instruments and Related Products Manufacturing for '
#                          'Measuring Displaying and Controlling Industrial '
#                          'Process Variables',
#                          'Other Measuring and Controlling Device Manufacturing',
#                          'Conveyor and Conveying Equipment Manufacturing',
#                          'Measuring Dispensing and Other Pumping Equipment '
#                          'Manufacturing',
#                          'Showcase Partition Shelving and Locker Manufacturing',
#                          'Search Detection Navigation Guidance Aeronautical '
#                          'and Nautical System and Instrument Manufacturing'],
#               'reason': 'These entities are general categories related to '
#                         'manufacturing or handling of various types of '
#                         'equipment, which could potentially include the given '
#                         'material handling screening system.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be '
#                                          'related to material handling '
#                                          'equipment, specifically a screening '
#                                          "system called 'IPCM-M extra'.",
#                  'entity': {'description1': 'Screening system IPCM-M extra',
#                             'group_name': 'Material handling'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'There are no additional '
#                                                   'assumptions that cannot be '
#                                                   'verified among the '
#                                                   'reference entities based on '
#                                                   'the given information.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicted '
#                                                   'assumptions among the '
#                                                   'reference entities based on '
#                                                   'the given information.'}},
#   'similar_to': [{'description1': 'Screening system ATEX multibox and hood',
#                   'group_name': 'Unpacking and screening station'},
#                  {'description1': 'Screening system UL drum and hood',
#                   'group_name': 'Unpacking and screening station'},
#                  {'description1': 'Stand',
#                   'group_name': 'Unpacking and screening station'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match for the specific '
#                             "manufacturing of 'Milled parts 2D' with a 'Build "
#                             "platform' description among the given entities."},
#   'general': {'entity': ['Cutting Tool and Machine Tool Accessory '
#                          'Manufacturing',
#                          'All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing'],
#               'reason': 'These entities describe manufacturing processes that '
#                         'could potentially involve milled metal parts or '
#                         'components, but are more general in scope.'},
#   'input_data': {'ai_input_description': "The input entity 'Milled parts 2D' "
#                                          "with the description 'Build "
#                                          "platform' seems to be referring to "
#                                          'the manufacturing of flat metal '
#                                          'parts using a milling process, '
#                                          'possibly for the construction of '
#                                          'platforms or bases.',
#                  'entity': {'description1': 'Build platform',
#                             'group_name': 'Milled parts 2D'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'The given entities do not '
#                                                   'provide additional details '
#                                                   'about the specific '
#                                                   'manufacturing process or '
#                                                   'products described in the '
#                                                   'input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the entities '
#                                                   'directly conflict with the '
#                                                   'assumptions made about the '
#                                                   'input entity.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': [],
#                   'reason': 'There are no exact matches for the input entity '
#                             "'Modular assemblies - Dosing system'."},
#   'general': {'entity': ['Measuring Dispensing and Other Pumping Equipment '
#                          'Manufacturing',
#                          'Totalizing Fluid Meter and Counting Device '
#                          'Manufacturing',
#                          'Instruments and Related Products Manufacturing for '
#                          'Measuring Displaying and Controlling Industrial '
#                          'Process Variables',
#                          'Other Measuring and Controlling Device '
#                          'Manufacturing'],
#               'reason': 'These entities are related to manufacturing equipment '
#                         'and systems for measuring, dispensing, and '
#                         'controlling various industrial processes, which can '
#                         'include dosing systems.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be related '
#                                          'to a dosing system, which is used '
#                                          'for dispensing or metering fluids or '
#                                          'other materials in a controlled '
#                                          'manner.',
#                  'entity': {'description1': 'Dosing system',
#                             'group_name': 'Modular assemblies'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'There are no additional '
#                                                   'assumptions required for '
#                                                   'the given input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicted '
#                                                   'assumptions for the given '
#                                                   'input entity.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match for the input entity in '
#                             'the given reference entities.'},
#   'general': {'entity': ['Engineered Wood Member except Truss Manufacturing',
#                          'Metal Kitchen Cookware Utensil Cutlery and Flatware '
#                          'except Precious Manufacturing',
#                          'Metal Crown Closure and Other Metal Stamping except '
#                          'Automotive',
#                          'Plumbing Fixture Fitting and Trim Manufacturing',
#                          'Motor Vehicle Steering and Suspension Components '
#                          'except Spring Manufacturing',
#                          'All Other Miscellaneous Electrical Equipment and '
#                          'Component Manufacturing',
#                          'Instruments and Related Products Manufacturing for '
#                          'Measuring Displaying and Controlling Industrial '
#                          'Process Variables'],
#               'reason': 'These entities are related to manufacturing processes '
#                         'or products, which could potentially use or involve '
#                         'accessories like the input entity.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be related '
#                                          'to accessories or components used in '
#                                          'manufacturing or assembly processes, '
#                                          "specifically a 'Z-guide' which could "
#                                          'be a type of guide or support used '
#                                          'in machinery.',
#                  'entity': {'description1': 'Z-guide used',
#                             'group_name': 'Other accessories'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'The reference entities do '
#                                                   'not provide additional '
#                                                   'information to verify the '
#                                                   'specific details of the '
#                                                   'input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicting '
#                                                   'assumptions in the '
#                                                   'reference entities.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': ['Search Detection Navigation Guidance '
#                              'Aeronautical and Nautical System and Instrument '
#                              'Manufacturing'],
#                   'reason': 'The input entity is a laser deflection head which '
#                             'is a component of a laser scanner, and this '
#                             'matches with the reference entity:'},
#   'general': {'entity': ['Optical Instrument and Lens Manufacturing',
#                          'Photofinishing Laboratories except One-Hour'],
#               'reason': 'The following entities are more general categories '
#                         'that a laser scanner could belong to:'},
#   'input_data': {'ai_input_description': 'The input entity seems to be a type '
#                                          'of laser scanner or sensor used for '
#                                          'industrial applications.',
#                  'entity': {'description1': 'Laser deflection head',
#                             'group_name': 'Scanner'}},
#   'related': {'additional_assumption': {'entity': ['Instruments and Related '
#                                                    'Products Manufacturing for '
#                                                    'Measuring Displaying and '
#                                                    'Controlling Industrial '
#                                                    'Process Variables',
#                                                    'Other Measuring and '
#                                                    'Controlling Device '
#                                                    'Manufacturing',
#                                                    'Totalizing Fluid Meter and '
#                                                    'Counting Device '
#                                                    'Manufacturing',
#                                                    'Measuring Dispensing and '
#                                                    'Other Pumping Equipment '
#                                                    'Manufacturing',
#                                                    'Instrument Manufacturing '
#                                                    'for Measuring and Testing '
#                                                    'Electricity and Electrical '
#                                                    'Signals',
#                                                    'All Other Miscellaneous '
#                                                    'General Purpose Machinery '
#                                                    'Manufacturing',
#                                                    'All Other Miscellaneous '
#                                                    'Electrical Equipment and '
#                                                    'Component Manufacturing'],
#                                         'reason': 'The following entities '
#                                                   'require additional '
#                                                   'assumptions about the input '
#                                                   "entity's specific "
#                                                   'application or industry:'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicted '
#                                                   'assumptions among the '
#                                                   'reference entities.'}},
#   'similar_to': [{'description1': 'Scanner head system',
#                   'group_name': 'Scanner'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match among the given reference '
#                             "entities for the specific input entity 'Workpiece "
#                             "transport' with description 'High lift truck'."},
#   'general': {'entity': ['All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing'],
#               'reason': 'These entities are more general categories that could '
#                         "potentially include the input entity 'Workpiece "
#                         "transport' with description 'High lift truck'."},
#   'input_data': {'ai_input_description': "The input entity 'Workpiece "
#                                          "transport' with description 'High "
#                                          "lift truck' appears to be referring "
#                                          'to a type of industrial vehicle or '
#                                          'equipment used for transporting '
#                                          'materials or workpieces, likely in a '
#                                          'manufacturing or warehousing '
#                                          'setting. A high lift truck is a type '
#                                          'of forklift or lifting equipment '
#                                          'capable of reaching considerable '
#                                          'heights.',
#                  'entity': {'description1': 'High lift truck',
#                             'group_name': 'Workpiece transport'}},
#   'related': {'additional_assumption': {'entity': ['Overhead Traveling Crane '
#                                                    'Hoist and Monorail System '
#                                                    'Manufacturing',
#                                                    'Conveyor and Conveying '
#                                                    'Equipment Manufacturing',
#                                                    'All Other Miscellaneous '
#                                                    'General Purpose Machinery '
#                                                    'Manufacturing',
#                                                    'Elevator and Moving '
#                                                    'Stairway Manufacturing',
#                                                    'Showcase Partition '
#                                                    'Shelving and Locker '
#                                                    'Manufacturing'],
#                                         'reason': 'The input entity does not '
#                                                   'provide additional details '
#                                                   'about the specific '
#                                                   'application or industry it '
#                                                   'is used in.'},
#               'conflicted_assumption': {'entity': ['Industrial Truck Tractor '
#                                                    'Trailer and Stacker '
#                                                    'Machinery Manufacturing',
#                                                    'All Other Transportation '
#                                                    'Equipment Manufacturing',
#                                                    'Heavy Duty Truck '
#                                                    'Manufacturing'],
#                                         'reason': "The input entity's "
#                                                   "description of 'High lift "
#                                                   "truck' conflicts with "
#                                                   'entities related to '
#                                                   'manufacturing of '
#                                                   'transportation equipment or '
#                                                   'vehicles themselves.'}},
#   'similar_to': []}]
