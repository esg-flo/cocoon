# %%
import os
import sys
import logging
import warnings
import pandas as pd

from pprint import pprint
from cocoon.core.llm.bedrock import BedrockLLM
from cocoon.core.embeddings.bedrock import BedrockEmbeddings
from cocoon.search_service import find_similar_indices, find_entity_relation_matches_and_cluster
from cocoon.embedding_service import initialize_faiss_index_from_embeddings, create_embeddings
from cocoon.output_service import generate_output

warnings.filterwarnings("ignore")
logging.basicConfig(stream=sys.stdout, level=logging.INFO, format="%(levelname)s - %(message)s")

# %% [markdown]
# ## 1. Basic setup

# %%
# Set AWS Profile
os.environ["AWS_DEFAULT_PROFILE"] = "sagar-wip-cli"

# %%
# Basic config for path/location settings
output_model_name = "titan_g1"

folder_name = "testing"
input_file_name = "EOS_Run1"

files = {
    # Pre-computed embeddings for NAICS dataset
    "embeddings": f's3://esgflo-wip-eu-dev-rightwhale-vault-store/scope3/naics/{output_model_name}_embeddings_output.csv',
    
    # Location of input csv file
    "data": f's3://esgflo-wip-eu-dev-rightwhale-vault-store/scope3/{folder_name}/{input_file_name}.csv',
    # Location of embeddings computed based on the input csv file
    "embedded_data": f's3://esgflo-wip-eu-dev-rightwhale-vault-store/scope3/{folder_name}/{input_file_name}_embedded.csv',
    # Location of the output csv file
    "output": f's3://esgflo-wip-eu-dev-rightwhale-vault-store/scope3/{folder_name}/{input_file_name}_output.csv',
}

# %% [markdown]
# ## 2. Read Files
#
# This section deals with reading the input file and the pre-computed embeddings of NAICS database from the location provided above.

# %% [markdown]
# ### 2.1. Input File

# %%
# Read the data file
data_df = pd.read_csv(files["data"], encoding="latin-1")
data_df = data_df[data_df.columns[-2:]]
data_df.columns = ["description1", "group_name"]
data_df = data_df[["group_name", "description1"]]

# Extract the columns to use in the future
columns_to_use = data_df.columns

# Create a label i.e., a concatenation of all the useful columns
data_df["label"] = data_df.apply(lambda x: ",".join(x), axis=1)

# Display the top 5 rows
data_df.head()
# Out:
# INFO - Credentials found in config file: ~/.aws/config
#            group_name                              description1  \
# 0              Drives                              X-axis drive
# 1   Other accessories                              Z-guide used
# 2  Modular assemblies                             Dosing system
# 3             Coolers  Cooling system air-cooled 1.5kW complete
# 4             Scanner                       Scanner head system
#
#                                               label
# 0                               Drives,X-axis drive
# 1                    Other accessories,Z-guide used
# 2                  Modular assemblies,Dosing system
# 3  Coolers,Cooling system air-cooled 1.5kW complete
# 4                       Scanner,Scanner head system

# %% [markdown]
# ### 2.2. Pre-computed Embeddings of NAICS

# %%
# Load NAICS embeddings
reference_df = pd.read_csv(files["embeddings"])

# %%
reference_df.head()
# Out:
#                                                label index_ids  \
# 0                     Abrasive Product Manufacturing     [292]
# 1                             Adhesive Manufacturing     [253]
# 2  Administrative Management and General Manageme...     [800]
# 3                               Advertising Agencies     [811]
# 4         Advertising Material Distribution Services     [817]
#
#                                     2017 NAICS Title  \
# 0                     Abrasive Product Manufacturing
# 1                             Adhesive Manufacturing
# 2  Administrative Management and General Manageme...
# 3                               Advertising Agencies
# 4         Advertising Material Distribution Services
#
#                                            embedding
# 0  [0.828125, 0.47851562, 0.32421875, 0.3125, -0....
# 1  [0.8046875, -0.018798828, 0.21289062, 1.328125...
# 2  [-0.14453125, -0.24609375, 0.41015625, -0.3828...
# 3  [-0.3515625, 0.203125, 0.38671875, 0.58203125,...
# 4  [0.3359375, 0.19042969, 0.088378906, 0.5429687...

# %% [markdown]
# ## 3. Create embeddings of the `label` column in the input data

# %%
# Initialize the Embedding class
# Here, we're using the Titan-G1 Model from Bedrock

embed_model = BedrockEmbeddings(
    model_id="amazon.titan-embed-text-v1",
    aws_region_name="eu-central-1",
    dims=1536
)
# Out:
# INFO - Credentials found in config file: ~/.aws/config

# %%
# Create the embeddings of the `label` column in the input data
# Save the embeddings dataframe in the `output_csv_filepath` location

input_embedded_df = create_embeddings(
    embed_model = embed_model,
    df = data_df,
    output_csv_filepath = files["embedded_data"]
)
# Out:
# INFO - 'amazon.titan-embed-text-v1' used for Embedding Text
# INFO - All labels embedded and CSV updated.

# %%
input_embedded_df.head()
# Out:
#                                                label index_ids  \
# 0  AMCM Customized System M,Customized M 290-1 1k...       [5]
# 1       CO_ laser,CO2 laser FSV30SAG (30W, AIR, OEM)      [21]
# 2     Coolers,Cooler 1.5kW air/water cooler complete      [31]
# 3     Coolers,Cooler 4.5kW air/water cooler complete      [18]
# 4   Coolers,Cooling system air-cooled 1.5kW complete       [3]
#
#                  group_name                              description1  \
# 0  AMCM Customized System M        Customized M 290-1 1kW Digital Can
# 1                 CO_ laser        CO2 laser FSV30SAG (30W, AIR, OEM)
# 2                   Coolers    Cooler 1.5kW air/water cooler complete
# 3                   Coolers    Cooler 4.5kW air/water cooler complete
# 4                   Coolers  Cooling system air-cooled 1.5kW complete
#
#                                            embedding
# 0  [-0.140625, 0.42578125, -0.439453125, -0.03295...
# 1  [-0.16015625, 0.53125, 0.34375, -0.146484375, ...
# 2  [-0.609375, 1.1171875, -0.63671875, -0.1455078...
# 3  [-0.5, 1.078125, -0.75390625, -0.2119140625, -...
# 4  [-0.267578125, 1.453125, -0.5390625, 0.2470703...

# %% [markdown]
# ## 4. Initialize FAISS Index from NAICS Embeddings

# %%
# Load FAISS index
index = initialize_faiss_index_from_embeddings(
    embed_model=embed_model,
    df=reference_df
)

# %% [markdown]
# ## 5. Find Similar between Input Label Embeddings and NAICS Embeddings

# %%
# Find similar indexes between input embedded df and database index
distances, indexes = find_similar_indices(
    input_embedded_df,
    index
)

# %%
display(distances[:5])
display(indexes[:5])
# Out:
# array([[350.10736, 351.23447, 352.7542 , 370.46704, 388.22443, 389.4735 ,
#         392.26947, 393.13736, 394.7958 , 394.80554],
#        [425.91248, 451.0672 , 459.53387, 468.84985, 477.5291 , 477.86914,
#         485.52667, 495.46918, 498.49567, 498.9358 ],
#        [397.44446, 424.2782 , 427.17703, 433.45987, 443.7939 , 470.3966 ,
#         473.03143, 484.15982, 486.6496 , 499.37234],
#        [398.2353 , 422.08936, 431.43433, 433.5531 , 439.87164, 467.75195,
#         473.90787, 486.2905 , 492.7293 , 501.32294],
#        [392.77338, 434.71942, 438.53342, 452.29214, 453.3752 , 477.81686,
#         494.00903, 502.22293, 508.9557 , 525.5472 ]], dtype=float32)
# array([[ 33,  30,   8,  24, 494, 798, 902, 431, 425,  83],
#        [  8, 425,  33,  24,  30,  34, 431, 978, 508, 737],
#        [  8, 756, 994, 912, 809, 978, 425,  33, 534, 270],
#        [  8, 756, 912, 994, 809, 425, 978,  33, 534, 270],
#        [  8, 912, 994, 978, 425, 756, 809,  33, 534,  30]])

# %% [markdown]
# ## 6. Perform Entiry Relation Match and Clustering between Input Emeddings <> NAICS Embeddings <> Similar Indices

# %%
# Initialize the LLM model
# We're using the Claude Sonnet from AWS Bedrock

llm = BedrockLLM(
    model_id="anthropic.claude-3-sonnet-20240229-v1:0",
    region_name="us-east-1",
    model_kwargs={
        "temperature": 1
    }
)

# %%
# Perform the matching
find_entity_relation_matches_and_cluster(
    input_df = input_embedded_df, 
    similar_indexes = indexes, 
    refernece_df = reference_df, 
    llm = llm,
    columns_to_use=columns_to_use,
    verbose=False
)
# Out:
# INFO - Begin processing entity match for 43 rows
# INFO - 32 rows remain...
# INFO - 21 rows remain...
# INFO - 10 rows remain...
# INFO - Completed processing entity match

# %%
# Updated dataframe after performing entity relation match
input_embedded_df.head()
# Out:
#                                                label index_ids  \
# 0  AMCM Customized System M,Customized M 290-1 1k...       [5]
# 1       CO_ laser,CO2 laser FSV30SAG (30W, AIR, OEM)      [21]
# 2     Coolers,Cooler 1.5kW air/water cooler complete      [31]
# 3     Coolers,Cooler 4.5kW air/water cooler complete      [18]
# 4   Coolers,Cooling system air-cooled 1.5kW complete       [3]
#
#                  group_name                              description1  \
# 0  AMCM Customized System M        Customized M 290-1 1kW Digital Can
# 1                 CO_ laser        CO2 laser FSV30SAG (30W, AIR, OEM)
# 2                   Coolers    Cooler 1.5kW air/water cooler complete
# 3                   Coolers    Cooler 4.5kW air/water cooler complete
# 4                   Coolers  Cooling system air-cooled 1.5kW complete
#
#                                            embedding  \
# 0  [-0.140625, 0.42578125, -0.439453125, -0.03295...
# 1  [-0.16015625, 0.53125, 0.34375, -0.146484375, ...
# 2  [-0.609375, 1.1171875, -0.63671875, -0.1455078...
# 3  [-0.5, 1.078125, -0.75390625, -0.2119140625, -...
# 4  [-0.267578125, 1.453125, -0.5390625, 0.2470703...
#
#                                              matches
# 0  {'Input Entity Guess': 'The input entity appea...
# 1  {'Input Entity Guess': 'The input entity appea...
# 2  {'Input Entity Guess': 'The input entity seems...
# 3  {'Input Entity Guess': 'The input entity appea...
# 4  {'Input Entity Guess': 'The input entity seems...

# %% [markdown]
# ## 7. Generate output

# %%
output = generate_output(input_embedded_df)

# %%
pprint(output)
# Out:
# [{'exact_match': {'entity': [],
#                   'reason': 'None of the reference entities seem to be an '
#                             'exact match for the input entity.'},
#   'general': {'entity': ['All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing',
#                          'All Other Miscellaneous Electrical Equipment and '
#                          'Component Manufacturing'],
#               'reason': 'These entities are general categories that the input '
#                         'entity could potentially fall under, but they are too '
#                         'broad to be certain.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be some '
#                                          'kind of customized machinery or '
#                                          'equipment, potentially for '
#                                          'industrial or manufacturing '
#                                          'purposes.',
#                  'entity': {'description1': 'Customized M 290-1 1kW Digital '
#                                             'Can',
#                             'group_name': 'AMCM Customized System M'}},
#   'related': {'additional_assumption': {'entity': ['All Other Miscellaneous '
#                                                    'General Purpose Machinery '
#                                                    'Manufacturing',
#                                                    'All Other Miscellaneous '
#                                                    'Electrical Equipment and '
#                                                    'Component Manufacturing',
#                                                    'Air-Conditioning and Warm '
#                                                    'Air Heating Equipment and '
#                                                    'Commercial and Industrial '
#                                                    'Refrigeration Equipment '
#                                                    'Manufacturing',
#                                                    'Measuring Dispensing and '
#                                                    'Other Pumping Equipment '
#                                                    'Manufacturing',
#                                                    'Radio and Television '
#                                                    'Broadcasting and Wireless '
#                                                    'Communications Equipment '
#                                                    'Manufacturing',
#                                                    'Speed Changer Industrial '
#                                                    'High-Speed Drive and Gear '
#                                                    'Manufacturing',
#                                                    'Instruments and Related '
#                                                    'Products Manufacturing for '
#                                                    'Measuring Displaying and '
#                                                    'Controlling Industrial '
#                                                    'Process Variables',
#                                                    'Industrial and Commercial '
#                                                    'Fan and Blower and Air '
#                                                    'Purification Equipment '
#                                                    'Manufacturing',
#                                                    'Automatic Environmental '
#                                                    'Control Manufacturing for '
#                                                    'Residential Commercial and '
#                                                    'Appliance Use'],
#                                         'reason': 'The input entity does not '
#                                                   'provide enough details to '
#                                                   'make assumptions about its '
#                                                   'specific use or purpose.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'The input entity mentions '
#                                                   "it is a 'Digital Can' which "
#                                                   'conflicts with the '
#                                                   'assumptions of the '
#                                                   'reference entities about '
#                                                   'being machinery or '
#                                                   'equipment.'}},
#   'similar_to': [{'description1': 'EOS M 290 laser sinter system (Std, MP1)',
#                   'group_name': 'M2xx customer system'},
#                  {'description1': 'EOS M 290 laser sinter system',
#                   'group_name': 'M2xx customer system'},
#                  {'description1': 'hurryScan 20 scan module 1080nm, with AKS',
#                   'group_name': 'Scanner'},
#                  {'description1': 'Controller Charon RevC, 256MB RAM, MPC52',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Build platform DirectBase Al30',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'EOS M 400-4 stand alone (USA)',
#                   'group_name': 'M4xx customer system'},
#                  {'description1': 'Build platform DirectBase S22',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'EOSINT P396 laser sintering machine used',
#                   'group_name': 'P3xx customer system'},
#                  {'description1': 'EOS M 400-4 stand alone',
#                   'group_name': 'M4xx customer system'},
#                  {'description1': 'Powder conveyor IPCM-M extra',
#                   'group_name': 'Material handling'},
#                  {'description1': 'Screening system UL drum and hood',
#                   'group_name': 'Unpacking and screening station'},
#                  {'description1': 'Build platform',
#                   'group_name': 'Manufactured parts'},
#                  {'description1': 'Cooling system air-cooled 1.5kW complete',
#                   'group_name': 'Coolers'},
#                  {'description1': 'Screening system ATEX multibox and hood',
#                   'group_name': 'Unpacking and screening station'},
#                  {'description1': 'Build platform M400 steel',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Build platform',
#                   'group_name': 'Milled parts 2D'},
#                  {'description1': 'Model Yb-Fiber Laser YLR-200-AC-Y14',
#                   'group_name': 'Fiber laser'},
#                  {'description1': 'Laser cooler air/water P802-18644-AW',
#                   'group_name': 'Coolers'},
#                  {'description1': 'Neslab Thermo Flex 2500 air-water cooler',
#                   'group_name': 'Coolers'},
#                  {'description1': 'CO2 laser FSV30SAG (30W, AIR, OEM)',
#                   'group_name': 'CO_ laser'},
#                  {'description1': 'Cooler 1.5kW air/water cooler complete',
#                   'group_name': 'Coolers'},
#                  {'description1': 'Screening system IPCM-M extra',
#                   'group_name': 'Material handling'},
#                  {'description1': 'Exchange frame 676',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Multibox',
#                   'group_name': 'Material handling'},
#                  {'description1': 'Build platform titanium Ti64 (Ti6Al4V)',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Coater complete P7xx assembly',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Cooler 4.5kW air/water cooler complete',
#                   'group_name': 'Coolers'},
#                  {'description1': 'MQS complete',
#                   'group_name': 'Material handling'},
#                  {'description1': 'Z-guide used',
#                   'group_name': 'Other accessories'},
#                  {'description1': 'YLR-400WC-Y14 laser with',
#                   'group_name': 'Fiber laser'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'None of the entities directly match a CO2 laser.'},
#   'general': {'entity': ['Air-Conditioning and Warm Air Heating Equipment and '
#                          'Commercial and Industrial Refrigeration Equipment '
#                          'Manufacturing',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing',
#                          'All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing',
#                          'All Other Miscellaneous Manufacturing',
#                          'Instruments and Related Products Manufacturing for '
#                          'Measuring Displaying and Controlling Industrial '
#                          'Process Variables'],
#               'reason': 'These entities encompass broad categories of '
#                         'manufacturing and machinery, which could potentially '
#                         'include CO2 lasers.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be a CO2 '
#                                          'laser used for industrial or '
#                                          'manufacturing purposes.',
#                  'entity': {'description1': 'CO2 laser FSV30SAG (30W, AIR, '
#                                             'OEM)',
#                             'group_name': 'CO_ laser'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'None of the entities '
#                                                   'require additional '
#                                                   'assumptions beyond what is '
#                                                   'provided in the input '
#                                                   'entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the entities '
#                                                   'directly conflict with the '
#                                                   'attributes of the input '
#                                                   'entity.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match for the specific input '
#                             'entity.'},
#   'general': {'entity': ['Air-Conditioning and Warm Air Heating Equipment and '
#                          'Commercial and Industrial Refrigeration Equipment '
#                          'Manufacturing',
#                          'Warm Air Heating and Air-Conditioning Equipment and '
#                          'Supplies Merchant Wholesalers',
#                          'Refrigeration Equipment and Supplies Merchant '
#                          'Wholesalers',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing',
#                          'All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing'],
#               'reason': 'These reference entities cover general categories '
#                         'related to cooling and refrigeration equipment '
#                         'manufacturing and distribution.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be about a '
#                                          'cooler, specifically an air/water '
#                                          'cooler with a cooling capacity of '
#                                          '1.5kW.',
#                  'entity': {'description1': 'Cooler 1.5kW air/water cooler '
#                                             'complete',
#                             'group_name': 'Coolers'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities seem to make '
#                                                   'additional assumptions '
#                                                   'beyond the given input '
#                                                   'entity details.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities directly conflict '
#                                                   'with the input entity '
#                                                   'details.'}},
#   'similar_to': [{'description1': 'Cooling system air-cooled 1.5kW complete',
#                   'group_name': 'Coolers'}]},
#  {'exact_match': {'entity': ['Air-Conditioning and Warm Air Heating Equipment '
#                              'and Commercial and Industrial Refrigeration '
#                              'Equipment Manufacturing'],
#                   'reason': "The input entity mentions a 'cooler' which is a "
#                             'type of air conditioning or refrigeration '
#                             "equipment, specifically an 'air/water cooler', "
#                             'which matches the description of these entities.'},
#   'general': {'entity': ['Plumbing and Heating Equipment and Supplies '
#                          'Hydronics Merchant Wholesalers',
#                          'Steam and Air-Conditioning Supply',
#                          'Warm Air Heating and Air-Conditioning Equipment and '
#                          'Supplies Merchant Wholesalers',
#                          'Refrigeration Equipment and Supplies Merchant '
#                          'Wholesalers',
#                          'Electrical Apparatus and Equipment Wiring Supplies '
#                          'and Related Equipment Merchant Wholesalers'],
#               'reason': 'Entities 2, 3, 4, 5, and 10 describe various merchant '
#                         'wholesalers or supply companies that could '
#                         'potentially deal with air conditioning, '
#                         'refrigeration, or related equipment, but are more '
#                         'general categories.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be '
#                                          'describing a water-cooled air '
#                                          'conditioning or refrigeration unit '
#                                          'for commercial or industrial use.',
#                  'entity': {'description1': 'Cooler 4.5kW air/water cooler '
#                                             'complete',
#                             'group_name': 'Coolers'}},
#   'related': {'additional_assumption': {'entity': ['Turbine and Turbine '
#                                                    'Generator Set Units '
#                                                    'Manufacturing',
#                                                    'All Other Miscellaneous '
#                                                    'General Purpose Machinery '
#                                                    'Manufacturing'],
#                                         'reason': 'Some entities like 7 and 8 '
#                                                   'appear to be related to '
#                                                   'manufacturing different '
#                                                   'types of machinery or '
#                                                   'equipment, but additional '
#                                                   'assumptions would be needed '
#                                                   'to determine if they are '
#                                                   'specifically relevant to '
#                                                   'the air/water cooler '
#                                                   'described.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the other entities '
#                                                   'directly conflict with the '
#                                                   'details provided in the '
#                                                   'input entity.'}},
#   'similar_to': [{'description1': 'Cooling system air-cooled 1.5kW complete',
#                   'group_name': 'Coolers'},
#                  {'description1': 'Laser cooler air/water P802-18644-AW',
#                   'group_name': 'Coolers'},
#                  {'description1': 'Neslab Thermo Flex 2500 air-water cooler',
#                   'group_name': 'Coolers'}]},
#  {'exact_match': {'entity': ['Air-Conditioning and Warm Air Heating Equipment '
#                              'and Commercial and Industrial Refrigeration '
#                              'Equipment Manufacturing'],
#                   'reason': 'The input entity is a cooling system air-cooled '
#                             '1.5kW complete which matches the description of '
#                             'air conditioning and refrigeration equipment '
#                             'manufacturing.'},
#   'general': {'entity': ['Steam and Air-Conditioning Supply',
#                          'Warm Air Heating and Air-Conditioning Equipment and '
#                          'Supplies Merchant Wholesalers',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing',
#                          'Plumbing and Heating Equipment and Supplies '
#                          'Hydronics Merchant Wholesalers',
#                          'Refrigeration Equipment and Supplies Merchant '
#                          'Wholesalers',
#                          'All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing',
#                          'All Other Miscellaneous Electrical Equipment and '
#                          'Component Manufacturing'],
#               'reason': 'These entities are general categories that include '
#                         'air conditioning and cooling equipment, but are '
#                         'broader in scope.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be about a '
#                                          'cooling system or air conditioning '
#                                          'equipment for industrial or '
#                                          'commercial use.',
#                  'entity': {'description1': 'Cooling system air-cooled 1.5kW '
#                                             'complete',
#                             'group_name': 'Coolers'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'There are no additional '
#                                                   'assumptions required for '
#                                                   'the reference entities '
#                                                   'based on the provided input '
#                                                   'entity details.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicted '
#                                                   'assumptions identified in '
#                                                   'the reference entities.'}},
#   'similar_to': [{'description1': 'Laser cooler air/water P802-18644-AW',
#                   'group_name': 'Coolers'},
#                  {'description1': 'Neslab Thermo Flex 2500 air-water cooler',
#                   'group_name': 'Coolers'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match among the given reference '
#                             "entities for the specific 'Laser cooler air/water "
#                             "P802-18644-AW' product."},
#   'general': {'entity': ['Steam and Air-Conditioning Supply',
#                          'Warm Air Heating and Air-Conditioning Equipment and '
#                          'Supplies Merchant Wholesalers',
#                          'Refrigeration Equipment and Supplies Merchant '
#                          'Wholesalers',
#                          'Electrical Apparatus and Equipment Wiring Supplies '
#                          'and Related Equipment Merchant Wholesalers',
#                          'Other Electronic Parts and Equipment Merchant '
#                          'Wholesalers'],
#               'reason': 'These entities are general categories that could '
#                         'potentially include laser cooler equipment, but are '
#                         'too broad to be a direct match.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be '
#                                          'related to laser cooler equipment '
#                                          'for air or water cooling, likely an '
#                                          'industrial or commercial product.',
#                  'entity': {'description1': 'Laser cooler air/water '
#                                             'P802-18644-AW',
#                             'group_name': 'Coolers'}},
#   'related': {'additional_assumption': {'entity': ['Air-Conditioning and Warm '
#                                                    'Air Heating Equipment and '
#                                                    'Commercial and Industrial '
#                                                    'Refrigeration Equipment '
#                                                    'Manufacturing',
#                                                    'Industrial and Commercial '
#                                                    'Fan and Blower and Air '
#                                                    'Purification Equipment '
#                                                    'Manufacturing',
#                                                    'All Other Miscellaneous '
#                                                    'General Purpose Machinery '
#                                                    'Manufacturing',
#                                                    'All Other Miscellaneous '
#                                                    'Electrical Equipment and '
#                                                    'Component Manufacturing'],
#                                         'reason': 'Some reference entities may '
#                                                   'be related but require '
#                                                   'additional assumptions '
#                                                   'about the specific cooling '
#                                                   'technology or application.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no conflicted '
#                                                   'assumptions among the '
#                                                   'reference entities.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': ['Air-Conditioning and Warm Air Heating Equipment '
#                              'and Commercial and Industrial Refrigeration '
#                              'Equipment Manufacturing'],
#                   'reason': "The input entity 'Neslab Thermo Flex 2500 "
#                             "air-water cooler' directly matches an air-water "
#                             'cooler product.'},
#   'general': {'entity': ['Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing',
#                          'All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing'],
#               'reason': 'These entities are more general categories that could '
#                         'include air-water coolers.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be '
#                                          'related to an air-water cooler used '
#                                          'for industrial or commercial '
#                                          'purposes.',
#                  'entity': {'description1': 'Neslab Thermo Flex 2500 air-water '
#                                             'cooler',
#                             'group_name': 'Coolers'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'None of the entities make '
#                                                   'additional assumptions '
#                                                   'beyond what is stated in '
#                                                   'the input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the entities '
#                                                   'directly conflict with the '
#                                                   'provided input entity '
#                                                   'details.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match for the input entity '
#                             'among the given reference entities.'},
#   'general': {'entity': ['Special Die and Tool Die Set Jig and Fixture '
#                          'Manufacturing',
#                          'Engineered Wood Member except Truss Manufacturing',
#                          'Showcase Partition Shelving and Locker Manufacturing',
#                          'Cutting Tool and Machine Tool Accessory '
#                          'Manufacturing',
#                          'Precision Turned Product Manufacturing',
#                          'Aluminum Foundries except Die-Casting'],
#               'reason': 'These entities are related to manufacturing processes '
#                         'and products, which is a more general category that '
#                         'could include the input entity.'},
#   'input_data': {'ai_input_description': "The input entity 'Cut pieces' with "
#                                          "the description 'Build platform "
#                                          "DirectBase Al30' seems to be related "
#                                          'to manufacturing processes, '
#                                          'specifically the cutting or shaping '
#                                          'of materials, potentially for '
#                                          'construction or industrial purposes.',
#                  'entity': {'description1': 'Build platform DirectBase Al30',
#                             'group_name': 'Cut pieces'}},
#   'related': {'additional_assumption': {'entity': ['Guided Missile and Space '
#                                                    'Vehicle Propulsion Unit '
#                                                    'and Propulsion Unit Parts '
#                                                    'Manufacturing',
#                                                    'Turbine and Turbine '
#                                                    'Generator Set Units '
#                                                    'Manufacturing'],
#                                         'reason': 'Some of the reference '
#                                                   'entities involve additional '
#                                                   'assumptions or details '
#                                                   'beyond what is specified in '
#                                                   'the input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'The input entity does not '
#                                                   'provide enough details to '
#                                                   'identify conflicting '
#                                                   'assumptions with any of the '
#                                                   'reference entities.'}},
#   'similar_to': [{'description1': 'Build platform DirectBase S22',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Build platform M400 steel',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Build platform titanium Ti64 (Ti6Al4V)',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Exchange frame',
#                   'group_name': 'Cut pieces'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match for the input entity '
#                             'among the given reference entities.'},
#   'general': {'entity': ['Industrial Truck Tractor Trailer and Stacker '
#                          'Machinery Manufacturing',
#                          'Sewing Needlework and Piece Goods Stores',
#                          'All Other Leather Good and Allied Product '
#                          'Manufacturing',
#                          'Plumbing Fixture Fitting and Trim Manufacturing',
#                          'Showcase Partition Shelving and Locker '
#                          'Manufacturing'],
#               'reason': 'Some reference entities are more general categories '
#                         "that could potentially encompass the input entity's "
#                         'description.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be about '
#                                          'building a platform or base for '
#                                          'something, possibly involving '
#                                          'cutting or shaping wood pieces.',
#                  'entity': {'description1': 'Build platform DirectBase S22',
#                             'group_name': 'Cut pieces'}},
#   'related': {'additional_assumption': {'entity': ['Cut Stock Resawing Lumber '
#                                                    'and Planing',
#                                                    'Lumber Plywood Millwork '
#                                                    'and Wood Panel Merchant '
#                                                    'Wholesalers',
#                                                    'Engineered Wood Member '
#                                                    'except Truss Manufacturing',
#                                                    'Special Die and Tool Die '
#                                                    'Set Jig and Fixture '
#                                                    'Manufacturing'],
#                                         'reason': 'Some reference entities '
#                                                   'involve additional '
#                                                   'assumptions beyond the '
#                                                   "input entity's description, "
#                                                   'such as specific '
#                                                   'manufacturing processes or '
#                                                   'product types.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities directly conflict '
#                                                   "with the input entity's "
#                                                   'description.'}},
#   'similar_to': [{'description1': 'Build platform M400 steel',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Build platform titanium Ti64 (Ti6Al4V)',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Build platform',
#                   'group_name': 'Manufactured parts'},
#                  {'description1': 'Build platform',
#                   'group_name': 'Milled parts 2D'},
#                  {'description1': 'Exchange frame', 'group_name': 'Cut pieces'},
#                  {'description1': 'Blade cassette II (blue) coater P7',
#                   'group_name': 'Manufactured parts'}]},
#  {'exact_match': {'entity': ['Cut Stock Resawing Lumber and Planing'],
#                   'reason': "The input entity 'Cut pieces' directly matches "
#                             'the description of this entity.'},
#   'general': {'entity': ['Metal Tank Heavy Gauge Manufacturing',
#                          'Fabricated Pipe and Pipe Fitting Manufacturing',
#                          'Iron and Steel Pipe and Tube Manufacturing from '
#                          'Purchased Steel',
#                          'Ornamental and Architectural Metal Work '
#                          'Manufacturing'],
#               'reason': 'These entities involve manufacturing metal products, '
#                         'which is a broader category than the specific cutting '
#                         'of pieces described in the input.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be about '
#                                          'cutting or resawing lumber or metal '
#                                          'components for use in manufacturing '
#                                          'or construction.',
#                  'entity': {'description1': 'Build platform M400 steel',
#                             'group_name': 'Cut pieces'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'There are no additional '
#                                                   'assumptions required for '
#                                                   'these entities based on the '
#                                                   'given information.'},
#               'conflicted_assumption': {'entity': ['Engineered Wood Member '
#                                                    'except Truss '
#                                                    'Manufacturing'],
#                                         'reason': "The description1 'Build "
#                                                   "platform M400 steel' "
#                                                   'conflicts with the '
#                                                   'manufacturing of wood '
#                                                   'members.'}},
#   'similar_to': [{'description1': 'Build platform titanium Ti64 (Ti6Al4V)',
#                   'group_name': 'Cut pieces'},
#                  {'description1': 'Exchange frame',
#                   'group_name': 'Cut pieces'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'There are no exact matches among the reference '
#                             'entities that directly correspond to cutting or '
#                             'machining titanium alloy parts.'},
#   'general': {'entity': ['Precision Turned Product Manufacturing',
#                          'Cutting Tool and Machine Tool Accessory '
#                          'Manufacturing'],
#               'reason': "The 'Cutting Tool and Machine Tool Accessory "
#                         "Manufacturing' and 'Precision Turned Product "
#                         "Manufacturing' entities are more general categories "
#                         'that could potentially include the manufacturing of '
#                         'titanium alloy parts through cutting and machining '
#                         'processes.'},
#   'input_data': {'ai_input_description': 'The input entity is likely related '
#                                          'to manufacturing of metal components '
#                                          'or parts, specifically involving '
#                                          'cutting or machining processes for '
#                                          'titanium alloy.',
#                  'entity': {'description1': 'Build platform titanium Ti64 '
#                                             '(Ti6Al4V)',
#                             'group_name': 'Cut pieces'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities make additional '
#                                                   'assumptions beyond what is '
#                                                   'stated in the input '
#                                                   'entity.'},
#               'conflicted_assumption': {'entity': ['Plumbing Fixture Fitting '
#                                                    'and Trim Manufacturing'],
#                                         'reason': "The 'Plumbing Fixture "
#                                                   'Fitting and Trim '
#                                                   "Manufacturing' entity is "
#                                                   'conflicted because it is '
#                                                   'focused on plumbing '
#                                                   'fixtures rather than '
#                                                   'titanium alloy parts.'}},
#   'similar_to': [{'description1': 'Build platform',
#                   'group_name': 'Milled parts 2D'},
#                  {'description1': 'Build platform',
#                   'group_name': 'Manufactured parts'},
#                  {'description1': 'Exchange frame 676',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Coater complete P7xx assembly',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Exchange frame', 'group_name': 'Cut pieces'},
#                  {'description1': 'Controller Charon RevC, 256MB RAM, MPC52',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Blade cassette II (blue) coater P7',
#                   'group_name': 'Manufactured parts'},
#                  {'description1': 'X-axis drive', 'group_name': 'Drives'},
#                  {'description1': 'Dosing system',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Laser deflection head',
#                   'group_name': 'Scanner'}]},
#  {'exact_match': {'entity': ['Folding Paperboard Box Manufacturing'],
#                   'reason': 'The input entity is about cutting pieces and '
#                             'exchanging frames, which directly matches with'},
#   'general': {'entity': ['Showcase Partition Shelving and Locker Manufacturing',
#                          'Special Die and Tool Die Set Jig and Fixture '
#                          'Manufacturing',
#                          'Lumber Plywood Millwork and Wood Panel Merchant '
#                          'Wholesalers',
#                          'Piece Goods Notions and Other Dry Goods Merchant '
#                          'Wholesalers',
#                          'All Other Leather Good and Allied Product '
#                          'Manufacturing'],
#               'reason': 'These entities are more general categories related to '
#                         'woodworking, manufacturing, or dealing with wood '
#                         'products'},
#   'input_data': {'ai_input_description': "The input entity 'Cut pieces' with "
#                                          "description 'Exchange frame' seems "
#                                          'to be related to woodworking or '
#                                          'manufacturing involving cutting '
#                                          'materials into pieces and '
#                                          'potentially exchanging or assembling '
#                                          'frames or structures.',
#                  'entity': {'description1': 'Exchange frame',
#                             'group_name': 'Cut pieces'}},
#   'related': {'additional_assumption': {'entity': ['Sewing Needlework and '
#                                                    'Piece Goods Stores',
#                                                    'Upholstered Household '
#                                                    'Furniture Manufacturing'],
#                                         'reason': 'The details about sewing, '
#                                                   'needlework, or upholstered '
#                                                   'furniture are additional '
#                                                   'assumptions not mentioned '
#                                                   'in the input entity'},
#               'conflicted_assumption': {'entity': ['Cut Stock Resawing Lumber '
#                                                    'and Planing',
#                                                    'Engineered Wood Member '
#                                                    'except Truss '
#                                                    'Manufacturing'],
#                                         'reason': 'The details about resawing '
#                                                   'lumber, planing, or truss '
#                                                   'manufacturing are '
#                                                   'conflicted with the input '
#                                                   "entity's focus on cutting "
#                                                   'pieces and exchanging '
#                                                   'frames'}},
#   'similar_to': [{'description1': 'Exchange frame 676',
#                   'group_name': 'Modular assemblies'},
#                  {'description1': 'Coater complete P7xx assembly',
#                   'group_name': 'Modular assemblies'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'None of the reference entities directly match the '
#                             'input entity.'},
#   'general': {'entity': ['Speed Changer Industrial High-Speed Drive and Gear '
#                          'Manufacturing',
#                          'All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing',
#                          'Measuring Dispensing and Other Pumping Equipment '
#                          'Manufacturing',
#                          'Bolt Nut Screw Rivet and Washer Manufacturing',
#                          'Turbine and Turbine Generator Set Units '
#                          'Manufacturing',
#                          'All Other Miscellaneous Electrical Equipment and '
#                          'Component Manufacturing',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing'],
#               'reason': 'These entities are related to manufacturing various '
#                         'types of industrial machinery and components, which '
#                         'could potentially include X-axis drives.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be '
#                                          'related to X-axis drive components '
#                                          'used in machinery or industrial '
#                                          'equipment.',
#                  'entity': {'description1': 'X-axis drive',
#                             'group_name': 'Drives'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities require additional '
#                                                   'assumptions beyond the '
#                                                   'information provided in the '
#                                                   'input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities directly conflict '
#                                                   'with the input entity.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': [],
#                   'reason': 'None of the reference entities directly match the '
#                             'input entity.'},
#   'general': {'entity': ['All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing',
#                          'Instruments and Related Products Manufacturing for '
#                          'Measuring Displaying and Controlling Industrial '
#                          'Process Variables'],
#               'reason': 'The input entity is a specific model of a fiber '
#                         'laser, which could be considered a type of industrial '
#                         'and commercial equipment or machinery.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be related '
#                                          'to a fiber laser model called '
#                                          "'Yb-Fiber Laser YLR-200-AC-Y14'.",
#                  'entity': {'description1': 'Model Yb-Fiber Laser '
#                                             'YLR-200-AC-Y14',
#                             'group_name': 'Fiber laser'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities seem to require '
#                                                   'additional assumptions '
#                                                   'about the input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities directly conflict '
#                                                   'with the input entity.'}},
#   'similar_to': [{'description1': 'YLR-400WC-Y14 laser with',
#                   'group_name': 'Fiber laser'},
#                  {'description1': 'YLR-400-SM-EOS ytterbium fiber laser',
#                   'group_name': 'Fiber laser'},
#                  {'description1': "Ytterbium fiber laser 'EOS-4' model YLR-",
#                   'group_name': 'Fiber laser'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match for the input entity '
#                             'among the reference entities provided.'},
#   'general': {'entity': ['Fiber Optic Cable Manufacturing'],
#               'reason': "The reference entity 'Fiber Optic Cable "
#                         "Manufacturing' is a general category that may include "
#                         'fiber laser products like the one described in the '
#                         'input entity.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be '
#                                          'describing a type of fiber laser '
#                                          'product, specifically an ytterbium '
#                                          'fiber laser called the '
#                                          'YLR-400-SM-EOS.',
#                  'entity': {'description1': 'YLR-400-SM-EOS ytterbium fiber '
#                                             'laser',
#                             'group_name': 'Fiber laser'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities make additional '
#                                                   'assumptions beyond the '
#                                                   'details provided in the '
#                                                   'input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities directly conflict '
#                                                   'with the details provided '
#                                                   'in the input entity.'}},
# ...
#                                                   'conflicts with the details '
#                                                   'provided in the input.'}},
#   'similar_to': [{'description1': 'hurryScan 20 scan module 1080nm, with AKS',
#                   'group_name': 'Scanner'}]},
#  {'exact_match': {'entity': [],
#                   'reason': "There doesn't appear to be an exact match among "
#                             'the given reference entities.'},
#   'general': {'entity': ['Other Electronic Parts and Equipment Merchant '
#                          'Wholesalers',
#                          'Computer and Computer Peripheral Equipment and '
#                          'Software Merchant Wholesalers',
#                          'All Other Miscellaneous General Purpose Machinery '
#                          'Manufacturing',
#                          'Household Appliances Electric Housewares and '
#                          'Consumer Electronics Merchant Wholesalers',
#                          'Photographic Equipment and Supplies Merchant '
#                          'Wholesalers',
#                          'Industrial Truck Tractor Trailer and Stacker '
#                          'Machinery Manufacturing'],
#               'reason': 'These reference entities are broadly related to '
#                         'manufacturing or wholesaling of various types of '
#                         'equipment or components, some of which could '
#                         'potentially include scanning or imaging '
#                         'technologies.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be a '
#                                          'scanning module for some device, '
#                                          'likely related to imaging or sensing '
#                                          'technology.',
#                  'entity': {'description1': 'hurryScan 20 scan module 1080nm, '
#                                             'with AKS',
#                             'group_name': 'Scanner'}},
#   'related': {'additional_assumption': {'entity': ['Search Detection '
#                                                    'Navigation Guidance '
#                                                    'Aeronautical and Nautical '
#                                                    'System and Instrument '
#                                                    'Manufacturing',
#                                                    'All Other Miscellaneous '
#                                                    'Electrical Equipment and '
#                                                    'Component Manufacturing',
#                                                    'Instruments and Related '
#                                                    'Products Manufacturing for '
#                                                    'Measuring Displaying and '
#                                                    'Controlling Industrial '
#                                                    'Process Variables'],
#                                         'reason': 'Some of the reference '
#                                                   'entities may be related to '
#                                                   'the input entity but would '
#                                                   'require additional '
#                                                   'assumptions beyond the '
#                                                   'information provided.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities directly conflict '
#                                                   'with the information '
#                                                   'provided about the input '
#                                                   'entity.'}},
#   'similar_to': [{'description1': 'Screening system UL drum and hood',
#                   'group_name': 'Unpacking and screening station'},
#                  {'description1': 'Screening system ATEX multibox and hood',
#                   'group_name': 'Unpacking and screening station'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'None of the reference entities exactly match the '
#                             "input entity's description of an unpacking and "
#                             'screening system with specific components like a '
#                             'multibox and hood.'},
#   'general': {'entity': ['Industrial Truck Tractor Trailer and Stacker '
#                          'Machinery Manufacturing',
#                          'Totalizing Fluid Meter and Counting Device '
#                          'Manufacturing',
#                          'Corrugated and Solid Fiber Box Manufacturing',
#                          'Gasket Packing and Sealing Device Manufacturing',
#                          'Folding Paperboard Box Manufacturing',
#                          'Paper Bag and Coated and Treated Paper Manufacturing',
#                          'Packing and Crating',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing'],
#               'reason': 'These entities are related to manufacturing or '
#                         'production of various industrial products and '
#                         'equipment, which could potentially include unpacking '
#                         'and screening systems like the input entity.'},
#   'input_data': {'ai_input_description': 'The input entity appears to be '
#                                          'related to equipment or systems used '
#                                          'for unpacking and screening items or '
#                                          'materials in industrial or '
#                                          'manufacturing settings. The '
#                                          'description suggests it involves an '
#                                          'ATEX-certified screening system with '
#                                          'a multibox and hood, likely for '
#                                          'handling potentially hazardous or '
#                                          'explosive materials.',
#                  'entity': {'description1': 'Screening system ATEX multibox '
#                                             'and hood',
#                             'group_name': 'Unpacking and screening station'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'The reference entities do '
#                                                   'not provide enough '
#                                                   'information to make '
#                                                   'additional assumptions '
#                                                   'beyond the details given in '
#                                                   "the input entity's "
#                                                   'description.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities directly conflict '
#                                                   'with the details provided '
#                                                   "in the input entity's "
#                                                   'description.'}},
#   'similar_to': [{'description1': 'Screening system UL drum and hood',
#                   'group_name': 'Unpacking and screening station'}]},
#  {'exact_match': {'entity': [],
#                   'reason': "The input entity 'Unpacking and screening "
#                             "station' with a description 'Screening system UL "
#                             "drum and hood' does not appear to have an exact "
#                             'match among the provided reference entities.'},
#   'general': {'entity': ['Packing and Crating',
#                          'Corrugated and Solid Fiber Box Manufacturing',
#                          'Folding Paperboard Box Manufacturing',
#                          'Showcase Partition Shelving and Locker Manufacturing',
#                          'Industrial Truck Tractor Trailer and Stacker '
#                          'Machinery Manufacturing',
#                          'Industrial and Commercial Fan and Blower and Air '
#                          'Purification Equipment Manufacturing'],
#               'reason': 'These entities involve manufacturing or production '
#                         'activities related to various types of containers, '
#                         'packaging materials, or industrial equipment, which '
#                         "are generally relevant to the input entity's "
#                         'description of an unpacking and screening station.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be related '
#                                          'to a station or system for unpacking '
#                                          'and screening drums or containers, '
#                                          'potentially involving some kind of '
#                                          'ventilation or exhaust system.',
#                  'entity': {'description1': 'Screening system UL drum and hood',
#                             'group_name': 'Unpacking and screening station'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'There are no reference '
#                                                   'entities that require '
#                                                   'additional assumptions '
#                                                   'beyond what is specified in '
#                                                   'the input entity.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'There are no reference '
#                                                   'entities that directly '
#                                                   'conflict with the '
#                                                   'assumptions or details '
#                                                   'provided in the input '
#                                                   'entity.'}},
#   'similar_to': [{'description1': 'Stand',
#                   'group_name': 'Unpacking and screening station'}]},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match for the input entity '
#                             'among the reference entities.'},
#   'general': {'entity': ['Packing and Crating',
#                          'Folding Paperboard Box Manufacturing',
#                          'Industrial Truck Tractor Trailer and Stacker '
#                          'Machinery Manufacturing',
#                          'Corrugated and Solid Fiber Box Manufacturing',
#                          'Paper Bag and Coated and Treated Paper Manufacturing',
#                          'Gasket Packing and Sealing Device Manufacturing'],
#               'reason': 'Some of the reference entities are related to '
#                         'packaging, manufacturing, or handling products, which '
#                         'could be considered general categories for an '
#                         'unpacking and screening station.'},
#   'input_data': {'ai_input_description': 'The input entity seems to be '
#                                          'describing a station or area for '
#                                          'unpacking and screening items or '
#                                          'packages.',
#                  'entity': {'description1': 'Stand',
#                             'group_name': 'Unpacking and screening station'}},
#   'related': {'additional_assumption': {'entity': [],
#                                         'reason': 'The input entity does not '
#                                                   'provide additional '
#                                                   'assumptions beyond '
#                                                   'describing an unpacking and '
#                                                   'screening station.'},
#               'conflicted_assumption': {'entity': [],
#                                         'reason': 'None of the reference '
#                                                   'entities directly conflict '
#                                                   'with the assumptions made '
#                                                   'in the input entity.'}},
#   'similar_to': []},
#  {'exact_match': {'entity': [],
#                   'reason': 'There is no exact match for the input entity '
#                             'among the reference entities.'},
#   'general': {'entity': ['Industrial Truck Tractor Trailer and Stacker '
#                          'Machinery Manufacturing',
#                          'Conveyor and Conveying Equipment Manufacturing',
#                          'All Other Transportation Equipment Manufacturing'],
#               'reason': 'The following reference entities are general '
#                         'categories or types of machinery that could '
#                         "potentially include the input entity's description, "
#                         'but they are not specific enough to be an exact '
#                         'match.'},
#   'input_data': {'ai_input_description': "The input entity 'Workpiece "
#                                          "transport' with the description "
#                                          "'High lift truck' seems to be "
#                                          'referring to industrial vehicles or '
#                                          'machinery used for transporting '
#                                          'heavy or large workpieces or '
#                                          'materials within a manufacturing or '
#                                          'construction setting.',
#                  'entity': {'description1': 'High lift truck',
#                             'group_name': 'Workpiece transport'}},
#   'related': {'additional_assumption': {'entity': ['All Other Miscellaneous '
#                                                    'General Purpose Machinery '
#                                                    'Manufacturing'],
#                                         'reason': 'The input entity does not '
#                                                   'provide additional details '
#                                                   'about the specific type of '
#                                                   'machinery or its '
#                                                   'application, so the '
#                                                   'following reference '
#                                                   'entities require additional '
#                                                   'assumptions:'},
#               'conflicted_assumption': {'entity': ['Freight Transportation '
#                                                    'Arrangement',
#                                                    'General Freight Trucking '
#                                                    'Long-Distance Less Than '
#                                                    'Truckload'],
#                                         'reason': 'The input entity is '
#                                                   'describing a specific type '
#                                                   'of vehicle or machinery '
#                                                   'used for transporting '
#                                                   'workpieces, which conflicts '
#                                                   'with the assumptions of the '
#                                                   'following reference '
#                                                   'entities:'}},
#   'similar_to': []}]

# %%
output
# Out:
# [{'input_data': {'entity': {'group_name': 'AMCM Customized System M',
#     'description1': 'Customized M 290-1 1kW Digital Can'},
#    'ai_input_description': 'The input entity appears to be some kind of customized machinery or equipment, potentially for industrial or manufacturing purposes.'},
#   'exact_match': {'reason': 'None of the reference entities seem to be an exact match for the input entity.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': "The input entity mentions it is a 'Digital Can' which conflicts with the assumptions of the reference entities about being machinery or equipment.",
#     'entity': []},
#    'additional_assumption': {'reason': 'The input entity does not provide enough details to make assumptions about its specific use or purpose.',
#     'entity': ['All Other Miscellaneous General Purpose Machinery Manufacturing',
#      'All Other Miscellaneous Electrical Equipment and Component Manufacturing',
#      'Air-Conditioning and Warm Air Heating Equipment and Commercial and Industrial Refrigeration Equipment Manufacturing',
#      'Measuring Dispensing and Other Pumping Equipment Manufacturing',
#      'Radio and Television Broadcasting and Wireless Communications Equipment Manufacturing',
#      'Speed Changer Industrial High-Speed Drive and Gear Manufacturing',
#      'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables',
#      'Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing',
#      'Automatic Environmental Control Manufacturing for Residential Commercial and Appliance Use']}},
#   'similar_to': [{'group_name': 'M2xx customer system',
#     'description1': 'EOS M 290 laser sinter system (Std, MP1)'},
#    {'group_name': 'M2xx customer system',
#     'description1': 'EOS M 290 laser sinter system'},
#    {'group_name': 'Scanner',
#     'description1': 'hurryScan 20 scan module 1080nm, with AKS'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Controller Charon RevC, 256MB RAM, MPC52'},
#    {'group_name': 'Cut pieces',
#     'description1': 'Build platform DirectBase Al30'},
#    {'group_name': 'M4xx customer system',
#     'description1': 'EOS M 400-4 stand alone (USA)'},
#    {'group_name': 'Cut pieces',
#     'description1': 'Build platform DirectBase S22'},
#    {'group_name': 'P3xx customer system',
#     'description1': 'EOSINT P396 laser sintering machine used'},
#    {'group_name': 'M4xx customer system',
#     'description1': 'EOS M 400-4 stand alone'},
#    {'group_name': 'Material handling',
#     'description1': 'Powder conveyor IPCM-M extra'},
#    {'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system UL drum and hood'},
#    {'group_name': 'Manufactured parts', 'description1': 'Build platform'},
#    {'group_name': 'Coolers',
#     'description1': 'Cooling system air-cooled 1.5kW complete'},
#    {'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system ATEX multibox and hood'},
#    {'group_name': 'Cut pieces', 'description1': 'Build platform M400 steel'},
#    {'group_name': 'Milled parts 2D', 'description1': 'Build platform'},
#    {'group_name': 'Fiber laser',
#     'description1': 'Model Yb-Fiber Laser YLR-200-AC-Y14'},
#    {'group_name': 'Coolers',
#     'description1': 'Laser cooler air/water P802-18644-AW'},
#    {'group_name': 'Coolers',
#     'description1': 'Neslab Thermo Flex 2500 air-water cooler'},
#    {'group_name': 'CO_ laser',
#     'description1': 'CO2 laser FSV30SAG (30W, AIR, OEM)'},
#    {'group_name': 'Coolers',
#     'description1': 'Cooler 1.5kW air/water cooler complete'},
#    {'group_name': 'Material handling',
#     'description1': 'Screening system IPCM-M extra'},
#    {'group_name': 'Modular assemblies', 'description1': 'Exchange frame 676'},
#    {'group_name': 'Material handling', 'description1': 'Multibox'},
#    {'group_name': 'Cut pieces',
#     'description1': 'Build platform titanium Ti64 (Ti6Al4V)'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Coater complete P7xx assembly'},
#    {'group_name': 'Coolers',
#     'description1': 'Cooler 4.5kW air/water cooler complete'},
#    {'group_name': 'Material handling', 'description1': 'MQS complete'},
#    {'group_name': 'Other accessories', 'description1': 'Z-guide used'},
#    {'group_name': 'Fiber laser', 'description1': 'YLR-400WC-Y14 laser with'}],
#   'general': {'reason': 'These entities are general categories that the input entity could potentially fall under, but they are too broad to be certain.',
#    'entity': ['All Other Miscellaneous General Purpose Machinery Manufacturing',
#     'All Other Miscellaneous Electrical Equipment and Component Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'CO_ laser',
#     'description1': 'CO2 laser FSV30SAG (30W, AIR, OEM)'},
#    'ai_input_description': 'The input entity appears to be a CO2 laser used for industrial or manufacturing purposes.'},
#   'exact_match': {'reason': 'None of the entities directly match a CO2 laser.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the entities directly conflict with the attributes of the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'None of the entities require additional assumptions beyond what is provided in the input entity.',
#     'entity': []}},
#   'similar_to': [],
#   'general': {'reason': 'These entities encompass broad categories of manufacturing and machinery, which could potentially include CO2 lasers.',
#    'entity': ['Air-Conditioning and Warm Air Heating Equipment and Commercial and Industrial Refrigeration Equipment Manufacturing',
#     'Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing',
#     'All Other Miscellaneous General Purpose Machinery Manufacturing',
#     'All Other Miscellaneous Manufacturing',
#     'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables']}},
#  {'input_data': {'entity': {'group_name': 'Coolers',
#     'description1': 'Cooler 1.5kW air/water cooler complete'},
#    'ai_input_description': 'The input entity seems to be about a cooler, specifically an air/water cooler with a cooling capacity of 1.5kW.'},
#   'exact_match': {'reason': 'There is no exact match for the specific input entity.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the input entity details.',
#     'entity': []},
#    'additional_assumption': {'reason': 'None of the reference entities seem to make additional assumptions beyond the given input entity details.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Coolers',
#     'description1': 'Cooling system air-cooled 1.5kW complete'}],
#   'general': {'reason': 'These reference entities cover general categories related to cooling and refrigeration equipment manufacturing and distribution.',
#    'entity': ['Air-Conditioning and Warm Air Heating Equipment and Commercial and Industrial Refrigeration Equipment Manufacturing',
#     'Warm Air Heating and Air-Conditioning Equipment and Supplies Merchant Wholesalers',
#     'Refrigeration Equipment and Supplies Merchant Wholesalers',
#     'Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing',
#     'All Other Miscellaneous General Purpose Machinery Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Coolers',
#     'description1': 'Cooler 4.5kW air/water cooler complete'},
#    'ai_input_description': 'The input entity appears to be describing a water-cooled air conditioning or refrigeration unit for commercial or industrial use.'},
#   'exact_match': {'reason': "The input entity mentions a 'cooler' which is a type of air conditioning or refrigeration equipment, specifically an 'air/water cooler', which matches the description of these entities.",
#    'entity': ['Air-Conditioning and Warm Air Heating Equipment and Commercial and Industrial Refrigeration Equipment Manufacturing']},
#   'related': {'conflicted_assumption': {'reason': 'None of the other entities directly conflict with the details provided in the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'Some entities like 7 and 8 appear to be related to manufacturing different types of machinery or equipment, but additional assumptions would be needed to determine if they are specifically relevant to the air/water cooler described.',
#     'entity': ['Turbine and Turbine Generator Set Units Manufacturing',
#      'All Other Miscellaneous General Purpose Machinery Manufacturing']}},
#   'similar_to': [{'group_name': 'Coolers',
#     'description1': 'Cooling system air-cooled 1.5kW complete'},
#    {'group_name': 'Coolers',
#     'description1': 'Laser cooler air/water P802-18644-AW'},
#    {'group_name': 'Coolers',
#     'description1': 'Neslab Thermo Flex 2500 air-water cooler'}],
#   'general': {'reason': 'Entities 2, 3, 4, 5, and 10 describe various merchant wholesalers or supply companies that could potentially deal with air conditioning, refrigeration, or related equipment, but are more general categories.',
#    'entity': ['Plumbing and Heating Equipment and Supplies Hydronics Merchant Wholesalers',
#     'Steam and Air-Conditioning Supply',
#     'Warm Air Heating and Air-Conditioning Equipment and Supplies Merchant Wholesalers',
#     'Refrigeration Equipment and Supplies Merchant Wholesalers',
#     'Electrical Apparatus and Equipment Wiring Supplies and Related Equipment Merchant Wholesalers']}},
#  {'input_data': {'entity': {'group_name': 'Coolers',
#     'description1': 'Cooling system air-cooled 1.5kW complete'},
#    'ai_input_description': 'The input entity seems to be about a cooling system or air conditioning equipment for industrial or commercial use.'},
#   'exact_match': {'reason': 'The input entity is a cooling system air-cooled 1.5kW complete which matches the description of air conditioning and refrigeration equipment manufacturing.',
#    'entity': ['Air-Conditioning and Warm Air Heating Equipment and Commercial and Industrial Refrigeration Equipment Manufacturing']},
#   'related': {'conflicted_assumption': {'reason': 'There are no conflicted assumptions identified in the reference entities.',
#     'entity': []},
#    'additional_assumption': {'reason': 'There are no additional assumptions required for the reference entities based on the provided input entity details.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Coolers',
#     'description1': 'Laser cooler air/water P802-18644-AW'},
#    {'group_name': 'Coolers',
#     'description1': 'Neslab Thermo Flex 2500 air-water cooler'}],
#   'general': {'reason': 'These entities are general categories that include air conditioning and cooling equipment, but are broader in scope.',
#    'entity': ['Steam and Air-Conditioning Supply',
#     'Warm Air Heating and Air-Conditioning Equipment and Supplies Merchant Wholesalers',
#     'Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing',
#     'Plumbing and Heating Equipment and Supplies Hydronics Merchant Wholesalers',
#     'Refrigeration Equipment and Supplies Merchant Wholesalers',
#     'All Other Miscellaneous General Purpose Machinery Manufacturing',
#     'All Other Miscellaneous Electrical Equipment and Component Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Coolers',
#     'description1': 'Laser cooler air/water P802-18644-AW'},
#    'ai_input_description': 'The input entity appears to be related to laser cooler equipment for air or water cooling, likely an industrial or commercial product.'},
#   'exact_match': {'reason': "There is no exact match among the given reference entities for the specific 'Laser cooler air/water P802-18644-AW' product.",
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'There are no conflicted assumptions among the reference entities.',
#     'entity': []},
#    'additional_assumption': {'reason': 'Some reference entities may be related but require additional assumptions about the specific cooling technology or application.',
#     'entity': ['Air-Conditioning and Warm Air Heating Equipment and Commercial and Industrial Refrigeration Equipment Manufacturing',
#      'Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing',
#      'All Other Miscellaneous General Purpose Machinery Manufacturing',
#      'All Other Miscellaneous Electrical Equipment and Component Manufacturing']}},
#   'similar_to': [],
#   'general': {'reason': 'These entities are general categories that could potentially include laser cooler equipment, but are too broad to be a direct match.',
#    'entity': ['Steam and Air-Conditioning Supply',
#     'Warm Air Heating and Air-Conditioning Equipment and Supplies Merchant Wholesalers',
#     'Refrigeration Equipment and Supplies Merchant Wholesalers',
#     'Electrical Apparatus and Equipment Wiring Supplies and Related Equipment Merchant Wholesalers',
#     'Other Electronic Parts and Equipment Merchant Wholesalers']}},
#  {'input_data': {'entity': {'group_name': 'Coolers',
#     'description1': 'Neslab Thermo Flex 2500 air-water cooler'},
#    'ai_input_description': 'The input entity appears to be related to an air-water cooler used for industrial or commercial purposes.'},
#   'exact_match': {'reason': "The input entity 'Neslab Thermo Flex 2500 air-water cooler' directly matches an air-water cooler product.",
#    'entity': ['Air-Conditioning and Warm Air Heating Equipment and Commercial and Industrial Refrigeration Equipment Manufacturing']},
#   'related': {'conflicted_assumption': {'reason': 'None of the entities directly conflict with the provided input entity details.',
#     'entity': []},
#    'additional_assumption': {'reason': 'None of the entities make additional assumptions beyond what is stated in the input entity.',
#     'entity': []}},
#   'similar_to': [],
#   'general': {'reason': 'These entities are more general categories that could include air-water coolers.',
#    'entity': ['Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing',
#     'All Other Miscellaneous General Purpose Machinery Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Cut pieces',
#     'description1': 'Build platform DirectBase Al30'},
#    'ai_input_description': "The input entity 'Cut pieces' with the description 'Build platform DirectBase Al30' seems to be related to manufacturing processes, specifically the cutting or shaping of materials, potentially for construction or industrial purposes."},
#   'exact_match': {'reason': 'There is no exact match for the input entity among the given reference entities.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'The input entity does not provide enough details to identify conflicting assumptions with any of the reference entities.',
#     'entity': []},
#    'additional_assumption': {'reason': 'Some of the reference entities involve additional assumptions or details beyond what is specified in the input entity.',
#     'entity': ['Guided Missile and Space Vehicle Propulsion Unit and Propulsion Unit Parts Manufacturing',
#      'Turbine and Turbine Generator Set Units Manufacturing']}},
#   'similar_to': [{'group_name': 'Cut pieces',
#     'description1': 'Build platform DirectBase S22'},
#    {'group_name': 'Cut pieces', 'description1': 'Build platform M400 steel'},
#    {'group_name': 'Cut pieces',
#     'description1': 'Build platform titanium Ti64 (Ti6Al4V)'},
#    {'group_name': 'Cut pieces', 'description1': 'Exchange frame'}],
#   'general': {'reason': 'These entities are related to manufacturing processes and products, which is a more general category that could include the input entity.',
#    'entity': ['Special Die and Tool Die Set Jig and Fixture Manufacturing',
#     'Engineered Wood Member except Truss Manufacturing',
#     'Showcase Partition Shelving and Locker Manufacturing',
#     'Cutting Tool and Machine Tool Accessory Manufacturing',
#     'Precision Turned Product Manufacturing',
#     'Aluminum Foundries except Die-Casting']}},
#  {'input_data': {'entity': {'group_name': 'Cut pieces',
#     'description1': 'Build platform DirectBase S22'},
#    'ai_input_description': 'The input entity seems to be about building a platform or base for something, possibly involving cutting or shaping wood pieces.'},
#   'exact_match': {'reason': 'There is no exact match for the input entity among the given reference entities.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': "None of the reference entities directly conflict with the input entity's description.",
#     'entity': []},
#    'additional_assumption': {'reason': "Some reference entities involve additional assumptions beyond the input entity's description, such as specific manufacturing processes or product types.",
#     'entity': ['Cut Stock Resawing Lumber and Planing',
#      'Lumber Plywood Millwork and Wood Panel Merchant Wholesalers',
#      'Engineered Wood Member except Truss Manufacturing',
#      'Special Die and Tool Die Set Jig and Fixture Manufacturing']}},
#   'similar_to': [{'group_name': 'Cut pieces',
#     'description1': 'Build platform M400 steel'},
#    {'group_name': 'Cut pieces',
#     'description1': 'Build platform titanium Ti64 (Ti6Al4V)'},
#    {'group_name': 'Manufactured parts', 'description1': 'Build platform'},
#    {'group_name': 'Milled parts 2D', 'description1': 'Build platform'},
#    {'group_name': 'Cut pieces', 'description1': 'Exchange frame'},
#    {'group_name': 'Manufactured parts',
#     'description1': 'Blade cassette II (blue) coater P7'}],
#   'general': {'reason': "Some reference entities are more general categories that could potentially encompass the input entity's description.",
#    'entity': ['Industrial Truck Tractor Trailer and Stacker Machinery Manufacturing',
#     'Sewing Needlework and Piece Goods Stores',
#     'All Other Leather Good and Allied Product Manufacturing',
#     'Plumbing Fixture Fitting and Trim Manufacturing',
#     'Showcase Partition Shelving and Locker Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Cut pieces',
#     'description1': 'Build platform M400 steel'},
#    'ai_input_description': 'The input entity appears to be about cutting or resawing lumber or metal components for use in manufacturing or construction.'},
#   'exact_match': {'reason': "The input entity 'Cut pieces' directly matches the description of this entity.",
#    'entity': ['Cut Stock Resawing Lumber and Planing']},
#   'related': {'conflicted_assumption': {'reason': "The description1 'Build platform M400 steel' conflicts with the manufacturing of wood members.",
#     'entity': ['Engineered Wood Member except Truss Manufacturing']},
#    'additional_assumption': {'reason': 'There are no additional assumptions required for these entities based on the given information.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Cut pieces',
#     'description1': 'Build platform titanium Ti64 (Ti6Al4V)'},
#    {'group_name': 'Cut pieces', 'description1': 'Exchange frame'}],
#   'general': {'reason': 'These entities involve manufacturing metal products, which is a broader category than the specific cutting of pieces described in the input.',
#    'entity': ['Metal Tank Heavy Gauge Manufacturing',
#     'Fabricated Pipe and Pipe Fitting Manufacturing',
#     'Iron and Steel Pipe and Tube Manufacturing from Purchased Steel',
#     'Ornamental and Architectural Metal Work Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Cut pieces',
#     'description1': 'Build platform titanium Ti64 (Ti6Al4V)'},
#    'ai_input_description': 'The input entity is likely related to manufacturing of metal components or parts, specifically involving cutting or machining processes for titanium alloy.'},
#   'exact_match': {'reason': 'There are no exact matches among the reference entities that directly correspond to cutting or machining titanium alloy parts.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': "The 'Plumbing Fixture Fitting and Trim Manufacturing' entity is conflicted because it is focused on plumbing fixtures rather than titanium alloy parts.",
#     'entity': ['Plumbing Fixture Fitting and Trim Manufacturing']},
#    'additional_assumption': {'reason': 'None of the reference entities make additional assumptions beyond what is stated in the input entity.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Milled parts 2D',
#     'description1': 'Build platform'},
#    {'group_name': 'Manufactured parts', 'description1': 'Build platform'},
#    {'group_name': 'Modular assemblies', 'description1': 'Exchange frame 676'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Coater complete P7xx assembly'},
#    {'group_name': 'Cut pieces', 'description1': 'Exchange frame'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Controller Charon RevC, 256MB RAM, MPC52'},
#    {'group_name': 'Manufactured parts',
#     'description1': 'Blade cassette II (blue) coater P7'},
#    {'group_name': 'Drives', 'description1': 'X-axis drive'},
#    {'group_name': 'Modular assemblies', 'description1': 'Dosing system'},
#    {'group_name': 'Scanner', 'description1': 'Laser deflection head'}],
#   'general': {'reason': "The 'Cutting Tool and Machine Tool Accessory Manufacturing' and 'Precision Turned Product Manufacturing' entities are more general categories that could potentially include the manufacturing of titanium alloy parts through cutting and machining processes.",
#    'entity': ['Precision Turned Product Manufacturing',
#     'Cutting Tool and Machine Tool Accessory Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Cut pieces',
#     'description1': 'Exchange frame'},
#    'ai_input_description': "The input entity 'Cut pieces' with description 'Exchange frame' seems to be related to woodworking or manufacturing involving cutting materials into pieces and potentially exchanging or assembling frames or structures."},
#   'exact_match': {'reason': 'The input entity is about cutting pieces and exchanging frames, which directly matches with',
#    'entity': ['Folding Paperboard Box Manufacturing']},
#   'related': {'conflicted_assumption': {'reason': "The details about resawing lumber, planing, or truss manufacturing are conflicted with the input entity's focus on cutting pieces and exchanging frames",
#     'entity': ['Cut Stock Resawing Lumber and Planing',
#      'Engineered Wood Member except Truss Manufacturing']},
#    'additional_assumption': {'reason': 'The details about sewing, needlework, or upholstered furniture are additional assumptions not mentioned in the input entity',
#     'entity': ['Sewing Needlework and Piece Goods Stores',
#      'Upholstered Household Furniture Manufacturing']}},
#   'similar_to': [{'group_name': 'Modular assemblies',
#     'description1': 'Exchange frame 676'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Coater complete P7xx assembly'}],
#   'general': {'reason': 'These entities are more general categories related to woodworking, manufacturing, or dealing with wood products',
#    'entity': ['Showcase Partition Shelving and Locker Manufacturing',
#     'Special Die and Tool Die Set Jig and Fixture Manufacturing',
#     'Lumber Plywood Millwork and Wood Panel Merchant Wholesalers',
#     'Piece Goods Notions and Other Dry Goods Merchant Wholesalers',
#     'All Other Leather Good and Allied Product Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Drives',
#     'description1': 'X-axis drive'},
#    'ai_input_description': 'The input entity appears to be related to X-axis drive components used in machinery or industrial equipment.'},
#   'exact_match': {'reason': 'None of the reference entities directly match the input entity.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'None of the reference entities require additional assumptions beyond the information provided in the input entity.',
#     'entity': []}},
#   'similar_to': [],
#   'general': {'reason': 'These entities are related to manufacturing various types of industrial machinery and components, which could potentially include X-axis drives.',
#    'entity': ['Speed Changer Industrial High-Speed Drive and Gear Manufacturing',
#     'All Other Miscellaneous General Purpose Machinery Manufacturing',
#     'Measuring Dispensing and Other Pumping Equipment Manufacturing',
#     'Bolt Nut Screw Rivet and Washer Manufacturing',
#     'Turbine and Turbine Generator Set Units Manufacturing',
#     'All Other Miscellaneous Electrical Equipment and Component Manufacturing',
#     'Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Fiber laser',
#     'description1': 'Model Yb-Fiber Laser YLR-200-AC-Y14'},
#    'ai_input_description': "The input entity seems to be related to a fiber laser model called 'Yb-Fiber Laser YLR-200-AC-Y14'."},
#   'exact_match': {'reason': 'None of the reference entities directly match the input entity.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'None of the reference entities seem to require additional assumptions about the input entity.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Fiber laser',
#     'description1': 'YLR-400WC-Y14 laser with'},
#    {'group_name': 'Fiber laser',
#     'description1': 'YLR-400-SM-EOS ytterbium fiber laser'},
#    {'group_name': 'Fiber laser',
#     'description1': "Ytterbium fiber laser 'EOS-4' model YLR-"}],
#   'general': {'reason': 'The input entity is a specific model of a fiber laser, which could be considered a type of industrial and commercial equipment or machinery.',
#    'entity': ['All Other Miscellaneous General Purpose Machinery Manufacturing',
#     'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables']}},
#  {'input_data': {'entity': {'group_name': 'Fiber laser',
#     'description1': 'YLR-400-SM-EOS ytterbium fiber laser'},
#    'ai_input_description': 'The input entity seems to be describing a type of fiber laser product, specifically an ytterbium fiber laser called the YLR-400-SM-EOS.'},
#   'exact_match': {'reason': 'There is no exact match for the input entity among the reference entities provided.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the details provided in the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'None of the reference entities make additional assumptions beyond the details provided in the input entity.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Fiber laser',
#     'description1': "Ytterbium fiber laser 'EOS-4' model YLR-"},
#    {'group_name': 'Fiber laser', 'description1': 'YLR-400WC-Y14 laser with'}],
#   'general': {'reason': "The reference entity 'Fiber Optic Cable Manufacturing' is a general category that may include fiber laser products like the one described in the input entity.",
#    'entity': ['Fiber Optic Cable Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Fiber laser',
#     'description1': 'YLR-400WC-Y14 laser with'},
#    'ai_input_description': 'The input entity appears to be related to a fiber laser, specifically the YLR-400WC-Y14 model.'},
#   'exact_match': {'reason': 'None of the reference entities exactly match a fiber laser or the YLR-400WC-Y14 model.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the given information about the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'None of the reference entities require additional assumptions beyond what is stated in the input entity.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Fiber laser',
#     'description1': "Ytterbium fiber laser 'EOS-4' model YLR-"}],
#   'general': {'reason': "The reference entity 'Instruments and Related Products Manufacturing for Measuring, Displaying, and Controlling Industrial Process Variables' is a general category that could potentially include fiber lasers used for industrial processes.",
#    'entity': ['Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables']}},
#  {'input_data': {'entity': {'group_name': 'Fiber laser',
#     'description1': "Ytterbium fiber laser 'EOS-4' model YLR-"},
#    'ai_input_description': "The input entity appears to be related to a fiber laser, specifically an ytterbium fiber laser model called 'EOS-4' or 'YLR-'."},
#   'exact_match': {'reason': 'There are no exact matches among the reference entities for the input ytterbium fiber laser.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'There are no conflicted assumptions among the reference entities for the input ytterbium fiber laser.',
#     'entity': []},
#    'additional_assumption': {'reason': 'There are no additional assumptions that can be made based on the reference entities regarding the input ytterbium fiber laser.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Scanner',
#     'description1': 'Laser deflection head'},
#    {'group_name': 'Scanner',
#     'description1': 'hurryScan 20 scan module 1080nm, with AKS'},
#    {'group_name': 'Scanner', 'description1': 'Scanner head system'}],
#   'general': {'reason': 'Some reference entities are related to manufacturing and production of instruments, devices, or components that could potentially involve fiber lasers, but the relation is quite general.',
#    'entity': ['Search Detection Navigation Guidance Aeronautical and Nautical System and Instrument Manufacturing',
#     'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables',
#     'Totalizing Fluid Meter and Counting Device Manufacturing',
#     'Radio and Television Broadcasting and Wireless Communications Equipment Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'M2xx customer system',
#     'description1': 'EOS M 290 laser sinter system'},
#    'ai_input_description': 'The input entity appears to be a laser sintering 3D printer system used for manufacturing industrial products.'},
#   'exact_match': {'reason': 'The input entity is a laser sintering system for manufacturing, which matches with the manufacturing equipment category.',
#    'entity': ['All Other Miscellaneous General Purpose Machinery Manufacturing']},
#   'related': {'conflicted_assumption': {'reason': 'None of the entities conflict with the given details about the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': "No additional assumptions are needed as the input entity's purpose is clearly stated.",
#     'entity': []}},
#   'similar_to': [{'group_name': 'M2xx customer system',
#     'description1': 'EOS M 290 laser sinter system (Std, MP1)'},
#    {'group_name': 'P3xx customer system',
#     'description1': 'EOSINT P396 laser sintering machine used'},
#    {'group_name': 'M4xx customer system',
#     'description1': 'EOS M 400-4 stand alone (USA)'},
#    {'group_name': 'M4xx customer system',
#     'description1': 'EOS M 400-4 stand alone'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Controller Charon RevC, 256MB RAM, MPC52'},
#    {'group_name': 'Material handling',
#     'description1': 'Powder conveyor IPCM-M extra'},
#    {'group_name': 'Manufactured parts', 'description1': 'Build platform'},
#    {'group_name': 'Material handling', 'description1': 'Multibox'},
#    {'group_name': 'Material handling',
#     'description1': 'Screening system IPCM-M extra'},
#    {'group_name': 'Scanner', 'description1': 'Laser deflection head'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Coater complete P7xx assembly'},
#    {'group_name': 'Material handling', 'description1': 'MQS complete'},
#    {'group_name': 'Modular assemblies', 'description1': 'Exchange frame 676'},
#    {'group_name': 'Material handling', 'description1': 'New powder container'},
#    {'group_name': 'Material handling', 'description1': 'Docking station P3'},
#    {'group_name': 'Modular assemblies', 'description1': 'Dosing system'},
#    {'group_name': 'Manufactured parts',
#     'description1': 'Blade cassette II (blue) coater P7'}],
#   'general': {'reason': 'These entities are general categories related to manufacturing equipment and processes.',
#    'entity': ['Other Measuring and Controlling Device Manufacturing',
#     'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables',
#     'Measuring Dispensing and Other Pumping Equipment Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'M2xx customer system',
#     'description1': 'EOS M 290 laser sinter system (Std, MP1)'},
#    'ai_input_description': 'The input entity seems to be a laser sintering system used for 3D printing or additive manufacturing.'},
#   'exact_match': {'reason': "There is no exact match for the specific product 'EOS M 290 laser sinter system' mentioned in the input entity.",
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'None of the reference entities require additional assumptions beyond what is given in the input entity.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'P3xx customer system',
#     'description1': 'EOSINT P396 laser sintering machine used'},
#    {'group_name': 'M4xx customer system',
#     'description1': 'EOS M 400-4 stand alone (USA)'},
#    {'group_name': 'M4xx customer system',
#     'description1': 'EOS M 400-4 stand alone'},
#    {'group_name': 'Scanner',
#     'description1': 'hurryScan 20 scan module 1080nm, with AKS'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Controller Charon RevC, 256MB RAM, MPC52'},
#    {'group_name': 'Milled parts 2D', 'description1': 'Build platform'},
#    {'group_name': 'Material handling',
#     'description1': 'Powder conveyor IPCM-M extra'},
#    {'group_name': 'Manufactured parts', 'description1': 'Build platform'},
#    {'group_name': 'Material handling', 'description1': 'Multibox'},
#    {'group_name': 'Scanner', 'description1': 'Laser deflection head'},
#    {'group_name': 'Material handling',
#     'description1': 'Screening system IPCM-M extra'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Coater complete P7xx assembly'},
#    {'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system ATEX multibox and hood'},
#    {'group_name': 'Modular assemblies', 'description1': 'Exchange frame 676'},
#    {'group_name': 'Manufactured parts',
#     'description1': 'Blade cassette II (blue) coater P7'},
#    {'group_name': 'Other accessories', 'description1': 'Z-guide used'},
#    {'group_name': 'Material handling', 'description1': 'MQS complete'},
#    {'group_name': 'Material handling', 'description1': 'Docking station P3'},
#    {'group_name': 'Material handling', 'description1': 'New powder container'},
#    {'group_name': 'Modular assemblies', 'description1': 'Dosing system'},
#    {'group_name': 'Scanner', 'description1': 'Scanner head system'}],
#   'general': {'reason': 'These entities are related to manufacturing equipment and instruments, which could potentially include laser sintering systems used for additive manufacturing.',
#    'entity': ['Other Measuring and Controlling Device Manufacturing',
#     'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables',
#     'Printing Machinery and Equipment Manufacturing',
#     'All Other Miscellaneous General Purpose Machinery Manufacturing',
#     'Measuring Dispensing and Other Pumping Equipment Manufacturing',
#     'Totalizing Fluid Meter and Counting Device Manufacturing',
#     'All Other Miscellaneous Electrical Equipment and Component Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'M4xx customer system',
#     'description1': 'EOS M 400-4 stand alone'},
#    'ai_input_description': 'The input entity seems to be referring to a customer service system or product line related to electrical/electronic equipment, possibly for industrial or commercial applications.'},
#   'exact_match': {'reason': 'There is no exact match among the reference entities for the input entity.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the assumptions made about the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'Some of the reference entities may require additional assumptions beyond what is stated in the input entity description.',
#     'entity': ['Electrical Apparatus and Equipment Wiring Supplies and Related Equipment Merchant Wholesalers',
#      'Household Appliances Electric Housewares and Consumer Electronics Merchant Wholesalers',
#      'Search Detection Navigation Guidance Aeronautical and Nautical System and Instrument Manufacturing',
#      'Other Electronic Parts and Equipment Merchant Wholesalers']}},
#   'similar_to': [{'group_name': 'M4xx customer system',
#     'description1': 'EOS M 400-4 stand alone (USA)'},
#    {'group_name': 'P3xx customer system',
#     'description1': 'EOSINT P396 laser sintering machine used'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Controller Charon RevC, 256MB RAM, MPC52'},
#    {'group_name': 'Scanner',
#     'description1': 'hurryScan 20 scan module 1080nm, with AKS'},
#    {'group_name': 'Modular assemblies', 'description1': 'Exchange frame 676'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Coater complete P7xx assembly'},
#    {'group_name': 'Modular assemblies', 'description1': 'Dosing system'},
#    {'group_name': 'Scanner', 'description1': 'Laser deflection head'},
#    {'group_name': 'Scanner', 'description1': 'Scanner head system'}],
#   'general': {'reason': 'These entities are more general categories that could potentially encompass the input entity, but they are not specific enough to be an exact match.',
#    'entity': ['Photographic Equipment and Supplies Merchant Wholesalers',
#     'Plumbing and Heating Equipment and Supplies Hydronics Merchant Wholesalers',
#     'Roofing Siding and Insulation Material Merchant Wholesalers',
#     'Narrow Fabric Mills and Schiffli Machine Embroidery']}},
#  {'input_data': {'entity': {'group_name': 'M4xx customer system',
#     'description1': 'EOS M 400-4 stand alone (USA)'},
#    'ai_input_description': "The input entity appears to be referring to a photographic equipment or camera system called the 'M4xx customer system' which is likely manufactured by Canon."},
#   'exact_match': {'reason': "The input entity mentions 'EOS M 400-4' which seems to be a specific model of a Canon camera system. This matches the reference entity:",
#    'entity': ['Photographic Equipment and Supplies Merchant Wholesalers']},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the input entity details.',
#     'entity': []},
#    'additional_assumption': {'reason': "The input entity does not provide additional details about the intended use or distribution channels for the 'M4xx customer system'.",
#     'entity': ['Electrical Apparatus and Equipment Wiring Supplies and Related Equipment Merchant Wholesalers',
#      'Household Appliances Electric Housewares and Consumer Electronics Merchant Wholesalers',
#      'Motor Vehicle Parts Used Merchant Wholesalers',
#      'Plumbing and Heating Equipment and Supplies Hydronics Merchant Wholesalers',
#      'Other Electronic Parts and Equipment Merchant Wholesalers',
#      'Medical Dental and Hospital Equipment and Supplies Merchant Wholesalers',
#      'Other Professional Equipment and Supplies Merchant Wholesalers',
#      'Computer and Computer Peripheral Equipment and Software Merchant Wholesalers']}},
#   'similar_to': [],
#   'general': {'reason': 'The reference entity is a more general category that could potentially include photographic equipment like the input entity.',
#    'entity': ['Other Electronic Parts and Equipment Merchant Wholesalers']}},
#  {'input_data': {'entity': {'group_name': 'Manufactured parts',
#     'description1': 'Blade cassette II (blue) coater P7'},
#    'ai_input_description': 'The input entity seems to be related to a manufacturing process or equipment for coating or applying materials onto surfaces, potentially involving blades or cutting components.'},
#   'exact_match': {'reason': 'None of the reference entities exactly match the input entity description.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': "The input entity specifically mentions a 'Blade cassette II (blue) coater P7', which conflicts with the assumptions of the following reference entities:",
#     'entity': ['All Other Leather Good and Allied Product Manufacturing',
#      'Turbine and Turbine Generator Set Units Manufacturing',
#      'Motor Vehicle Parts Used Merchant Wholesalers']},
#    'additional_assumption': {'reason': 'None of the reference entities require additional assumptions beyond what is mentioned in the input entity description.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Modular assemblies',
#     'description1': 'Coater complete P7xx assembly'},
#    {'group_name': 'Modular assemblies',
#     'description1': 'Controller Charon RevC, 256MB RAM, MPC52'},
#    {'group_name': 'Material handling',
#     'description1': 'Powder conveyor IPCM-M extra'},
#    {'group_name': 'Material handling', 'description1': 'Docking station P3'},
#    {'group_name': 'Material handling', 'description1': 'New powder container'},
#    {'group_name': 'Material handling', 'description1': 'Multibox'},
#    {'group_name': 'Material handling', 'description1': 'MQS complete'},
#    {'group_name': 'Material handling',
#     'description1': 'Screening system IPCM-M extra'},
#    {'group_name': 'Modular assemblies', 'description1': 'Dosing system'}],
#   'general': {'reason': 'These reference entities are general categories that could potentially include the input entity, but they are too broad to establish a strong relation.',
#    'entity': ['All Other Miscellaneous General Purpose Machinery Manufacturing',
#     'All Other Miscellaneous Electrical Equipment and Component Manufacturing',
#     'Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing',
#     'Other Metal Valve and Pipe Fitting Manufacturing',
#     'Air-Conditioning and Warm Air Heating Equipment and Commercial and Industrial Refrigeration Equipment Manufacturing',
#     'Guided Missile and Space Vehicle Propulsion Unit and Propulsion Unit Parts Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Manufactured parts',
#     'description1': 'Build platform'},
#    'ai_input_description': "The input entity 'Manufactured parts' with description 'Build platform' seems to be related to manufacturing or production of physical components or structures."},
#   'exact_match': {'reason': 'There are no exact matches for the given input entity description.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': "The descriptions of entities 1, 2, 3, 4, and 5 indicate that they are related to specific types of manufacturing (e.g., turbines, wood products, pipe fittings, missiles, and propulsion units), which conflicts with the general 'Manufactured parts' description of the input entity.",
#     'entity': ['Turbine and Turbine Generator Set Units Manufacturing',
#      'Engineered Wood Member except Truss Manufacturing',
#      'Fabricated Pipe and Pipe Fitting Manufacturing',
#      'Other Guided Missile and Space Vehicle Parts and Auxiliary Equipment Manufacturing',
#      'Guided Missile and Space Vehicle Propulsion Unit and Propulsion Unit Parts Manufacturing']},
#    'additional_assumption': {'reason': 'The descriptions of entities 6, 7, 8, and 9 provide additional details about the types of machinery or components being manufactured, which cannot be verified from the input entity description.',
#     'entity': ['Industrial Truck Tractor Trailer and Stacker Machinery Manufacturing',
#      'All Other Miscellaneous General Purpose Machinery Manufacturing',
#      'Other Metal Valve and Pipe Fitting Manufacturing',
#      'Special Die and Tool Die Set Jig and Fixture Manufacturing']}},
#   'similar_to': [{'group_name': 'Milled parts 2D',
#     'description1': 'Build platform'}],
#   'general': {'reason': "Entity 10 'Showcase Partition Shelving and Locker Manufacturing' is a general category that could include the 'Build platform' description of the input entity.",
#    'entity': ['Showcase Partition Shelving and Locker Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Material handling',
#     'description1': 'Docking station P3'},
#    'ai_input_description': 'The input entity seems to be related to material handling equipment, specifically a docking station used for loading and unloading materials.'},
#   'exact_match': {'reason': 'There is no exact match for a docking station among the given reference entities.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'There are no conflicting details given about the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'There are no additional details that cannot be verified from the given information.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Material handling',
#     'description1': 'Multibox'},
#    {'group_name': 'Material handling', 'description1': 'MQS complete'},
#    {'group_name': 'Material handling',
#     'description1': 'Powder conveyor IPCM-M extra'},
#    {'group_name': 'Material handling',
#     'description1': 'New powder container'}],
#   'general': {'reason': 'These entities are related to general material handling, storage, and transportation equipment and operations, which the input entity falls under.',
#    'entity': ['Industrial Truck Tractor Trailer and Stacker Machinery Manufacturing',
#     'Other Warehousing and Storage',
#     'Conveyor and Conveying Equipment Manufacturing',
#     'General Freight Trucking Long-Distance Less Than Truckload',
#     'Construction Mining and Forestry Machinery and Equipment Rental and Leasing']}},
#  {'input_data': {'entity': {'group_name': 'Material handling',
#     'description1': 'MQS complete'},
#    'ai_input_description': "The input entity 'Material handling' with description 'MQS complete' seems to be referring to equipment, machinery, or services related to the handling and transportation of materials in industrial or manufacturing settings."},
#   'exact_match': {'reason': 'There are no exact matches for the input entity.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'There are no conflicting assumptions.',
#     'entity': []},
#    'additional_assumption': {'reason': 'There are no additional assumptions needed.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Material handling',
#     'description1': 'Multibox'},
#    {'group_name': 'Material handling',
#     'description1': 'Powder conveyor IPCM-M extra'},
#    {'group_name': 'Material handling',
#     'description1': 'Screening system IPCM-M extra'},
#    {'group_name': 'Material handling',
#     'description1': 'New powder container'}],
#   'general': {'reason': 'These entities are related to the general category of material handling equipment or services.',
#    'entity': ['Conveyor and Conveying Equipment Manufacturing',
#     'Industrial Truck Tractor Trailer and Stacker Machinery Manufacturing',
#     'Overhead Traveling Crane Hoist and Monorail System Manufacturing',
#     'Process Physical Distribution and Logistics Consulting Services']}},
#  {'input_data': {'entity': {'group_name': 'Material handling',
#     'description1': 'Multibox'},
#    'ai_input_description': 'The input entity appears to be related to material handling equipment or systems, particularly those involving multi-box or multi-container handling.'},
# ...
#     'entity': []},
#    'additional_assumption': {'reason': 'There are no additional assumptions needed to understand the input entity.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Scanner',
#     'description1': 'hurryScan 20 scan module 1080nm, with AKS'},
#    {'group_name': 'Scanner', 'description1': 'Laser deflection head'},
#    {'group_name': 'Unpacking and screening station', 'description1': 'Stand'},
#    {'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system UL drum and hood'},
#    {'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system ATEX multibox and hood'},
#    {'group_name': 'Scanner', 'description1': 'Scanner head system'},
#    {'group_name': 'Workpiece transport', 'description1': 'High lift truck'}],
#   'general': {'reason': 'Several reference entities are related to manufacturing of various products, which could potentially include the accessory described in the input entity.',
#    'entity': ['Engineered Wood Member except Truss Manufacturing',
#     'Metal Kitchen Cookware Utensil Cutlery and Flatware except Precious Manufacturing',
#     'Metal Crown Closure and Other Metal Stamping except Automotive',
#     'All Other Leather Good and Allied Product Manufacturing',
#     'Nonferrous Metal except Copper and Aluminum Rolling Drawing and Extruding',
#     'Plumbing Fixture Fitting and Trim Manufacturing',
#     'Motor Vehicle Steering and Suspension Components except Spring Manufacturing',
#     'All Other Miscellaneous Electrical Equipment and Component Manufacturing',
#     'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables']}},
#  {'input_data': {'entity': {'group_name': 'P3xx customer system',
#     'description1': 'EOSINT P396 laser sintering machine used'},
#    'ai_input_description': 'The input entity appears to be related to a laser sintering machine used in manufacturing, specifically for additive manufacturing or 3D printing of metal or plastic parts.'},
#   'exact_match': {'reason': "The input entity mentions an 'EOSINT P396 laser sintering machine' which is a specific product name that directly matches the manufacturing process described.",
#    'entity': ['Powder Metallurgy Part Manufacturing']},
#   'related': {'conflicted_assumption': {'reason': 'There are no conflicting details mentioned in the input entity description.',
#     'entity': []},
#    'additional_assumption': {'reason': 'No additional assumptions are required beyond the given information about it being a laser sintering machine for manufacturing.',
#     'entity': []}},
#   'similar_to': [],
#   'general': {'reason': 'These entities describe more general categories of manufacturing that could encompass laser sintering or additive manufacturing processes.',
#    'entity': ['Precision Turned Product Manufacturing',
#     'Guided Missile and Space Vehicle Propulsion Unit and Propulsion Unit Parts Manufacturing',
#     'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables',
#     'Power-Driven Handtool Manufacturing',
#     'Unlaminated Plastics Profile Shape Manufacturing',
#     'Metal Coating Engraving except Jewelry and Silverware and Allied Services to Manufacturers',
#     'Totalizing Fluid Meter and Counting Device Manufacturing',
#     'Special Die and Tool Die Set Jig and Fixture Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Scanner',
#     'description1': 'Laser deflection head'},
#    'ai_input_description': 'The input entity seems to be a laser scanner or a device that uses a laser beam to scan or detect objects.'},
#   'exact_match': {'reason': 'There is no exact match for a laser scanning device in the given reference entities.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'The reference entities 1, 3, 6, 7, 8, and 9 are related to manufacturing or measuring industrial processes, which conflicts with the assumption that the input entity is a laser scanning device.',
#     'entity': ['Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables',
#      'Totalizing Fluid Meter and Counting Device Manufacturing',
#      'Measuring Dispensing and Other Pumping Equipment Manufacturing',
#      'Instrument Manufacturing for Measuring and Testing Electricity and Electrical Signals',
#      'All Other Miscellaneous General Purpose Machinery Manufacturing',
#      'All Other Miscellaneous Electrical Equipment and Component Manufacturing']},
#    'additional_assumption': {'reason': 'None of the reference entities explicitly mention laser scanning or deflection, so assuming the input entity is a laser scanning device would require additional assumptions.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Scanner',
#     'description1': 'Scanner head system'},
#    {'group_name': 'Scanner',
#     'description1': 'hurryScan 20 scan module 1080nm, with AKS'}],
#   'general': {'reason': 'The reference entities 2, 4, and 5 are related to manufacturing or dealing with measuring, controlling, navigation, and optical instruments in general, which could potentially include laser scanning devices.',
#    'entity': ['Other Measuring and Controlling Device Manufacturing',
#     'Search Detection Navigation Guidance Aeronautical and Nautical System and Instrument Manufacturing',
#     'Optical Instrument and Lens Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Scanner',
#     'description1': 'Scanner head system'},
#    'ai_input_description': 'The input entity seems to be related to scanner equipment or devices used for scanning or imaging purposes.'},
#   'exact_match': {'reason': "There is no exact match among the given reference entities for the 'Scanner head system' described in the input.",
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities explicitly conflicts with the details provided in the input.',
#     'entity': []},
#    'additional_assumption': {'reason': 'Some of the reference entities may encompass scanner devices, but additional assumptions about their specific capabilities or applications would be required.',
#     'entity': ['Search Detection Navigation Guidance Aeronautical and Nautical System and Instrument Manufacturing',
#      'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables',
#      'Other Measuring and Controlling Device Manufacturing',
#      'All Other Miscellaneous General Purpose Machinery Manufacturing',
#      'All Other Miscellaneous Electrical Equipment and Component Manufacturing',
#      'Measuring Dispensing and Other Pumping Equipment Manufacturing']}},
#   'similar_to': [{'group_name': 'Scanner',
#     'description1': 'hurryScan 20 scan module 1080nm, with AKS'}],
#   'general': {'reason': 'These entities cover broader categories of manufacturing and equipment that could potentially include scanner devices as a subset.',
#    'entity': ['Search Detection Navigation Guidance Aeronautical and Nautical System and Instrument Manufacturing',
#     'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables',
#     'Other Measuring and Controlling Device Manufacturing',
#     'All Other Miscellaneous General Purpose Machinery Manufacturing',
#     'All Other Miscellaneous Electrical Equipment and Component Manufacturing',
#     'Measuring Dispensing and Other Pumping Equipment Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Scanner',
#     'description1': 'hurryScan 20 scan module 1080nm, with AKS'},
#    'ai_input_description': 'The input entity appears to be a scanning module for some device, likely related to imaging or sensing technology.'},
#   'exact_match': {'reason': "There doesn't appear to be an exact match among the given reference entities.",
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the information provided about the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'Some of the reference entities may be related to the input entity but would require additional assumptions beyond the information provided.',
#     'entity': ['Search Detection Navigation Guidance Aeronautical and Nautical System and Instrument Manufacturing',
#      'All Other Miscellaneous Electrical Equipment and Component Manufacturing',
#      'Instruments and Related Products Manufacturing for Measuring Displaying and Controlling Industrial Process Variables']}},
#   'similar_to': [{'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system UL drum and hood'},
#    {'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system ATEX multibox and hood'}],
#   'general': {'reason': 'These reference entities are broadly related to manufacturing or wholesaling of various types of equipment or components, some of which could potentially include scanning or imaging technologies.',
#    'entity': ['Other Electronic Parts and Equipment Merchant Wholesalers',
#     'Computer and Computer Peripheral Equipment and Software Merchant Wholesalers',
#     'All Other Miscellaneous General Purpose Machinery Manufacturing',
#     'Household Appliances Electric Housewares and Consumer Electronics Merchant Wholesalers',
#     'Photographic Equipment and Supplies Merchant Wholesalers',
#     'Industrial Truck Tractor Trailer and Stacker Machinery Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system ATEX multibox and hood'},
#    'ai_input_description': 'The input entity appears to be related to equipment or systems used for unpacking and screening items or materials in industrial or manufacturing settings. The description suggests it involves an ATEX-certified screening system with a multibox and hood, likely for handling potentially hazardous or explosive materials.'},
#   'exact_match': {'reason': "None of the reference entities exactly match the input entity's description of an unpacking and screening system with specific components like a multibox and hood.",
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': "None of the reference entities directly conflict with the details provided in the input entity's description.",
#     'entity': []},
#    'additional_assumption': {'reason': "The reference entities do not provide enough information to make additional assumptions beyond the details given in the input entity's description.",
#     'entity': []}},
#   'similar_to': [{'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system UL drum and hood'}],
#   'general': {'reason': 'These entities are related to manufacturing or production of various industrial products and equipment, which could potentially include unpacking and screening systems like the input entity.',
#    'entity': ['Industrial Truck Tractor Trailer and Stacker Machinery Manufacturing',
#     'Totalizing Fluid Meter and Counting Device Manufacturing',
#     'Corrugated and Solid Fiber Box Manufacturing',
#     'Gasket Packing and Sealing Device Manufacturing',
#     'Folding Paperboard Box Manufacturing',
#     'Paper Bag and Coated and Treated Paper Manufacturing',
#     'Packing and Crating',
#     'Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Unpacking and screening station',
#     'description1': 'Screening system UL drum and hood'},
#    'ai_input_description': 'The input entity seems to be related to a station or system for unpacking and screening drums or containers, potentially involving some kind of ventilation or exhaust system.'},
#   'exact_match': {'reason': "The input entity 'Unpacking and screening station' with a description 'Screening system UL drum and hood' does not appear to have an exact match among the provided reference entities.",
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'There are no reference entities that directly conflict with the assumptions or details provided in the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'There are no reference entities that require additional assumptions beyond what is specified in the input entity.',
#     'entity': []}},
#   'similar_to': [{'group_name': 'Unpacking and screening station',
#     'description1': 'Stand'}],
#   'general': {'reason': "These entities involve manufacturing or production activities related to various types of containers, packaging materials, or industrial equipment, which are generally relevant to the input entity's description of an unpacking and screening station.",
#    'entity': ['Packing and Crating',
#     'Corrugated and Solid Fiber Box Manufacturing',
#     'Folding Paperboard Box Manufacturing',
#     'Showcase Partition Shelving and Locker Manufacturing',
#     'Industrial Truck Tractor Trailer and Stacker Machinery Manufacturing',
#     'Industrial and Commercial Fan and Blower and Air Purification Equipment Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Unpacking and screening station',
#     'description1': 'Stand'},
#    'ai_input_description': 'The input entity seems to be describing a station or area for unpacking and screening items or packages.'},
#   'exact_match': {'reason': 'There is no exact match for the input entity among the reference entities.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'None of the reference entities directly conflict with the assumptions made in the input entity.',
#     'entity': []},
#    'additional_assumption': {'reason': 'The input entity does not provide additional assumptions beyond describing an unpacking and screening station.',
#     'entity': []}},
#   'similar_to': [],
#   'general': {'reason': 'Some of the reference entities are related to packaging, manufacturing, or handling products, which could be considered general categories for an unpacking and screening station.',
#    'entity': ['Packing and Crating',
#     'Folding Paperboard Box Manufacturing',
#     'Industrial Truck Tractor Trailer and Stacker Machinery Manufacturing',
#     'Corrugated and Solid Fiber Box Manufacturing',
#     'Paper Bag and Coated and Treated Paper Manufacturing',
#     'Gasket Packing and Sealing Device Manufacturing']}},
#  {'input_data': {'entity': {'group_name': 'Workpiece transport',
#     'description1': 'High lift truck'},
#    'ai_input_description': "The input entity 'Workpiece transport' with the description 'High lift truck' seems to be referring to industrial vehicles or machinery used for transporting heavy or large workpieces or materials within a manufacturing or construction setting."},
#   'exact_match': {'reason': 'There is no exact match for the input entity among the reference entities.',
#    'entity': []},
#   'related': {'conflicted_assumption': {'reason': 'The input entity is describing a specific type of vehicle or machinery used for transporting workpieces, which conflicts with the assumptions of the following reference entities:',
#     'entity': ['Freight Transportation Arrangement',
#      'General Freight Trucking Long-Distance Less Than Truckload']},
#    'additional_assumption': {'reason': 'The input entity does not provide additional details about the specific type of machinery or its application, so the following reference entities require additional assumptions:',
#     'entity': ['All Other Miscellaneous General Purpose Machinery Manufacturing']}},
#   'similar_to': [],
#   'general': {'reason': "The following reference entities are general categories or types of machinery that could potentially include the input entity's description, but they are not specific enough to be an exact match.",
#    'entity': ['Industrial Truck Tractor Trailer and Stacker Machinery Manufacturing',
#     'Conveyor and Conveying Equipment Manufacturing',
#     'All Other Transportation Equipment Manufacturing']}}]
